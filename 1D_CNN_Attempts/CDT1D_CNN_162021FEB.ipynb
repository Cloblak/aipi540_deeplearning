# %% [markdown]
# <a href="https://colab.research.google.com/github/Cloblak/aipi540_deeplearning/blob/main/1D_CNN_Attempts/CDT1D_CNN_162021FEB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install alpaca_trade_api
# Out:
# Collecting alpaca_trade_api
#   Downloading alpaca_trade_api-1.5.0-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.7 MB/s
# Collecting websocket-client<2,>=0.56.0
#   Downloading websocket_client-1.2.3-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.9 MB/s
# Collecting msgpack==1.0.2
#   Downloading msgpack-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (273 kB)
#      |████████████████████████████████| 273 kB 61.1 MB/s
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from alpaca_trade_api) (1.3.5)
# Collecting websockets<10,>=8.0
#   Downloading websockets-9.1-cp37-cp37m-manylinux2010_x86_64.whl (103 kB)
#      |████████████████████████████████| 103 kB 67.6 MB/s
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from alpaca_trade_api) (1.21.5)
# Collecting aiohttp==3.7.4
#   Downloading aiohttp-3.7.4-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 63.1 MB/s
# Collecting PyYAML==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 65.8 MB/s
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.7/dist-packages (from alpaca_trade_api) (1.24.3)
# Collecting deprecation==2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.7/dist-packages (from alpaca_trade_api) (2.23.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 71.6 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.2 MB/s
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca_trade_api) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca_trade_api) (21.4.0)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca_trade_api) (3.10.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation==2.1.0->alpaca_trade_api) (21.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.1->alpaca_trade_api) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.1->alpaca_trade_api) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18.1->alpaca_trade_api) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>2->alpaca_trade_api) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>2->alpaca_trade_api) (2021.10.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->deprecation==2.1.0->alpaca_trade_api) (3.0.7)
# Installing collected packages: multidict, yarl, async-timeout, websockets, websocket-client, PyYAML, msgpack, deprecation, aiohttp, alpaca-trade-api
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.3
#     Uninstalling msgpack-1.0.3:
#       Successfully uninstalled msgpack-1.0.3
# Successfully installed PyYAML-5.4.1 aiohttp-3.7.4 alpaca-trade-api-1.5.0 async-timeout-3.0.1 deprecation-2.1.0 msgpack-1.0.2 multidict-6.0.2 websocket-client-1.2.3 websockets-9.1 yarl-1.7.2

# %% [markdown]
# Features To Consider
#  - Targets are only predicting sell within market hours, i.e. at 1530, target is prediciting price for 1100 the next day.  Data from pre and post market is taken into consideration, and a sell or buy will be indicated if the price will flucuate after close.

# %%
# Import Dependencies
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.tensorboard import SummaryWriter
from torchsummary import summary
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from tqdm.notebook import tqdm
import alpaca_trade_api as tradeapi
from datetime import datetime, timedelta, tzinfo, timezone, time
import os.path
import ast
import threading
import math
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import warnings

# %%
random_seed = 182
torch.manual_seed(random_seed)

# %%
PAPER_API_KEY = "PKE39LILN9SL1FMJMFV7"
PAPER_SECRET_KEY = "TkU7fXH6WhP15MewgWlSnQG5RUoHGOPQ7yqlD6xq"
PAPER_BASE_URL = 'https://paper-api.alpaca.markets'

# %%
api = tradeapi.REST(PAPER_API_KEY, PAPER_SECRET_KEY, PAPER_BASE_URL, api_version='v2')

# %%
def prepost_train_test_validate_offset_data(api, ticker, interval, train_days=180, test_days=60, validate_days=30, offset_days = 0):
    ticker_data_dict = None
    ticker_data_dict = {}
    monthly_data_dict = None
    monthly_data_dict = {}
    interval_loop_data = None
    interval_loop_data = pd.DataFrame()
    stock_data = None
    
    days_to_collect = train_days + test_days + validate_days + offset_days

    TZ = 'US/Eastern'

    start = pd.to_datetime((datetime.now() - timedelta(days=days_to_collect)).strftime("%Y-%m-%d %H:%M"), utc=True)
    end = pd.to_datetime(datetime.now().strftime("%Y-%m-%d %H:%M"), utc=True)

    stock_data = api.get_bars(ticker, interval, start = start.isoformat(), end=end.isoformat(), adjustment="raw").df
    
    interval_loop_data = interval_loop_data.append(stock_data)
    df_start_ref = interval_loop_data.index[0]
    start_str_ref = pd.to_datetime(start, utc=True)

    while start_str_ref.value < ( pd.to_datetime(df_start_ref, utc=True) - pd.Timedelta(days=2.5)).value:
        end_new = pd.to_datetime(interval_loop_data.index[0].strftime("%Y-%m-%d %H:%M"), utc=True).isoformat()
        stock_data_new = None
        stock_data_new = api.get_bars(ticker, interval, start=start, end=end_new, adjustment="raw").df
        #stock_data_new = stock_data_new.reset_index()
        interval_loop_data = interval_loop_data.append(stock_data_new).sort_values(by=['index'], ascending=True)
        df_start_ref = interval_loop_data.index[0]
        
    stock_yr_min_df = interval_loop_data.copy()
    stock_yr_min_df["Open"] = stock_yr_min_df['open']
    stock_yr_min_df["High"]= stock_yr_min_df["high"]
    stock_yr_min_df["Low"] = stock_yr_min_df["low"]
    stock_yr_min_df["Close"] = stock_yr_min_df["close"]
    stock_yr_min_df["Volume"] = stock_yr_min_df["volume"]
    stock_yr_min_df["VolumeWeightedAvgPrice"] = stock_yr_min_df["vwap"]
    stock_yr_min_df["Time"] = stock_yr_min_df.index.tz_convert(TZ)
    stock_yr_min_df.index = stock_yr_min_df.index.tz_convert(TZ)
    final_df = stock_yr_min_df.filter(["Time", "Open", "High", "Low", "Close", "Volume", "VolumeWeightedAvgPrice"], axis = 1)
    
    first_day = final_df.index[0]
    traintest_day = final_df.index[-1] - pd.Timedelta(days= test_days+validate_days+offset_days)
    valtest_day = final_df.index[-1] - pd.Timedelta(days= test_days+offset_days)
    last_day = final_df.index[-1] - pd.Timedelta(days= offset_days)
    training_df =  final_df.loc[first_day:traintest_day] #(data_split - pd.Timedelta(days=1))]
    validate_df = final_df.loc[traintest_day:valtest_day]
    testing_df =  final_df.loc[valtest_day:last_day]
    full_train = final_df.loc[first_day:last_day]
    offset_df =  final_df.loc[last_day:]

    return training_df, validate_df, testing_df, full_train, offset_df, final_df, traintest_day, valtest_day

from datetime import date

train_start = date(2017, 2, 15)
train_end = date(2020, 3, 29)
train_delta = train_end - train_start
print(f'Number of days of Training Data {train_delta.days}')

val_day_num = 400
print(f'Number of days of Validation Data {val_day_num}')

test_start = train_end + timedelta(val_day_num)
test_end = date.today()
test_delta = (test_end - test_start)
print(f'Number of days of Holdout Test Data {test_delta.days}')

ticker = "CORN" # Ticker Symbol to Test
interval = "5Min" # Interval of bars
train_day_int = train_delta.days # Size of training set (Jan 2010 - Oct 2017)
val_day_int = val_day_num # Size of validation set
test_day_int = test_delta.days # Size of test set
offset_day_int = 0 # Number of days to off set the training data
train_raw, val_raw, test_raw, full_raw, offset_raw, complete_raw, traintest_day, testval_day = prepost_train_test_validate_offset_data(api, ticker, 
                                                                                     interval, 
                                                                                     train_days=train_day_int, 
                                                                                     test_days=test_day_int, 
                                                                                     validate_days=val_day_int,
                                                                                     offset_days = offset_day_int)

def timeFilterAndBackfill(df):
  """ 
  Prep df to be filled out for each trading day:
    Time Frame: 0930-1930
    Backfilling NaNs
    Adjusting Volume to Zero if no Trading data is present
      - Assumption is that there were no trades duing that time 

  We will build over lapping arrays by 30 min to give ourselfs more
  oppurtunities to predict during a given trading day 
  """
  
  df = df.between_time('07:29','17:29') # intial sorting of data

  TZ = 'US/Eastern' # define the correct timezone

  start_dateTime = pd.Timestamp(year = df.index[0].year, 
                                month = df.index[0].month, 
                                day = df.index[0].day, 
                                hour = 7, minute = 25, tz = TZ)

  end_dateTime = pd.Timestamp(year = df.index[-1].year, 
                              month = df.index[-1].month, 
                              day = df.index[-1].day, 
                              hour = 17, minute = 35, tz = TZ)

  # build blank index that has ever 5 min interval represented
  dateTime_index = pd.date_range(start_dateTime,
                                end_dateTime, 
                                freq='5min').tolist()

  dateTime_index_df = pd.DataFrame()
  dateTime_index_df["Time"] = dateTime_index 
  filtered_df = pd.merge_asof(dateTime_index_df, df,  
                              on='Time').set_index("Time").between_time('09:29','17:29')

  # create the close array by back filling NA, to represent no change in close
  closeset_list = []
  prev_c = None

  for c in filtered_df["Close"]:

    if prev_c == None:
      if math.isnan(c):
        prev_c = 0
        closeset_list.append(0)
      else:
        prev_c = c
        closeset_list.append(c)
    
    elif prev_c != None:
      if c == prev_c:
        closeset_list.append(c)
      elif math.isnan(c):
        closeset_list.append(prev_c)
      else:
        closeset_list.append(c)
        prev_c = c
    
  filtered_df["Close"] = closeset_list

  # create the volume
  volumeset_list = []
  prev_v = None

  for v in filtered_df["Volume"]:
    
    if prev_v == None:
      if math.isnan(v):
        prev_v = 0
        volumeset_list.append(0)
      else:
        prev_v = v
        volumeset_list.append(v)

    elif prev_v != None:
      if v == prev_v:
        volumeset_list.append(0)
        prev_v = v
      elif math.isnan(v):
        volumeset_list.append(0)
        prev_v = 0
      else:
        volumeset_list.append(v)
        prev_v = v

  filtered_df["Volume"] = volumeset_list
  
  adjvolumeset_list = []
  prev_v = None

  for v in filtered_df["VolumeWeightedAvgPrice"]:
    if prev_v == None:
      if math.isnan(v):
        prev_v = 0
        adjvolumeset_list.append(0)
      else:
        prev_v = v
        adjvolumeset_list.append(v)
    elif prev_v != None:
      if v == prev_v:
        adjvolumeset_list.append(0)
        prev_v = v
      elif math.isnan(v):
        adjvolumeset_list.append(0)
        prev_v = 0
      else:
        adjvolumeset_list.append(v)
        prev_v = v

  filtered_df["VolumeWeightedAvgPrice"] = adjvolumeset_list

  preped_df = filtered_df.backfill()

  return preped_df
# Out:
# Number of days of Training Data 1138
# Number of days of Validation Data 400
# Number of days of Holdout Test Data 290

# %%
train_raw[0:300]
# Out:
#                                                Time  ...  VolumeWeightedAvgPrice
# timestamp                                            ...
# 2017-02-15 09:30:00-05:00 2017-02-15 09:30:00-05:00  ...               19.782139
# 2017-02-15 09:35:00-05:00 2017-02-15 09:35:00-05:00  ...               19.770000
# 2017-02-15 09:40:00-05:00 2017-02-15 09:40:00-05:00  ...               19.751279
# 2017-02-15 09:45:00-05:00 2017-02-15 09:45:00-05:00  ...               19.780000
# 2017-02-15 10:00:00-05:00 2017-02-15 10:00:00-05:00  ...               19.778303
# ...                                             ...  ...                     ...
# 2017-02-24 11:30:00-05:00 2017-02-24 11:30:00-05:00  ...               19.330000
# 2017-02-24 11:40:00-05:00 2017-02-24 11:40:00-05:00  ...               19.318341
# 2017-02-24 11:55:00-05:00 2017-02-24 11:55:00-05:00  ...               19.314400
# 2017-02-24 12:05:00-05:00 2017-02-24 12:05:00-05:00  ...               19.323589
# 2017-02-24 12:10:00-05:00 2017-02-24 12:10:00-05:00  ...               19.320000
#
# [300 rows x 7 columns]

# %%
def buildTargets_VolOnly(full_df = full_raw, train_observations = train_raw.shape[0], 
                         val_observations = val_raw.shape[0], 
                         test_observations = test_raw.shape[0], 
                         alph = .55, volity_int = 10):

  """ 
  This function will take a complete set of train, val, and test data and return the targets.
  Volitility will be calculated over the 252 5min incriments 
  The Target shift is looking at 2 hours shift from current time
  """

  returns = np.log(full_df['Close']/(full_df['Close'].shift()))
  returns.fillna(0, inplace=True)
  volatility = returns.rolling(window=(volity_int)).std()*np.sqrt(volity_int)



  return volatility
  #return train_targets, val_targets, test_targets, full_targets

volatility = buildTargets_VolOnly()

fig = plt.figure(figsize=(15, 7))
ax1 = fig.add_subplot(1, 1, 1)
volatility.plot(ax=ax1, color = "red")
ax1.set_xlabel('Date')
ax1.set_ylabel('Volatility', color = "red")
ax1.set_title(f'Annualized volatility for {ticker}')
ax2 = ax1.twinx()
full_raw.Close.plot(ax=ax2, color = "blue")
ax2.set_ylabel('Close', color = "blue")
ax2.axvline(x=full_raw.index[train_raw.shape[0]])
ax2.axvline(x=full_raw.index[val_raw.shape[0]+train_raw.shape[0]])
plt.show()

# %%
train = timeFilterAndBackfill(train_raw)
val = timeFilterAndBackfill(val_raw)
test = timeFilterAndBackfill(test_raw)

train = train[train.index.dayofweek <= 4].copy()
val = val[val.index.dayofweek <= 4].copy()
test = test[test.index.dayofweek <= 4].copy()

train["Open"] = np.where((train["Volume"] == 0), train["Close"], train["Open"])
train["High"] = np.where((train["Volume"] == 0), train["Close"], train["High"])
train["Low"] = np.where((train["Volume"] == 0), train["Close"], train["Low"])

val["Open"] = np.where((val["Volume"] == 0), val["Close"], val["Open"])
val["High"] = np.where((val["Volume"] == 0), val["Close"], val["High"])
val["Low"] = np.where((val["Volume"] == 0), val["Close"], val["Low"])

test["Open"] = np.where((test["Volume"] == 0), test["Close"], test["Open"])
test["High"] = np.where((test["Volume"] == 0), test["Close"], test["High"])
test["Low"] = np.where((test["Volume"] == 0), test["Close"], test["Low"])

def strided_axis0(a, L, overlap=1):
    if L==overlap:
        raise Exception("Overlap arg must be smaller than length of windows")
    S = L - overlap
    nd0 = ((len(a)-L)//S)+1
    if nd0*S-S!=len(a)-L:
        warnings.warn("Not all elements were covered")
    m,n = a.shape
    s0,s1 = a.strides
    return np.lib.stride_tricks.as_strided(a, shape=(nd0,L,n), strides=(S*s0,s0,s1))

# OLDER CODE WITHOUT OVERLAP OF LABELING
# def blockshaped(arr, nrows, ncols):
#     """
#     Return an array of shape (n, nrows, ncols) where
#     n * nrows * ncols = arr.size

#     If arr is a 2D array, the returned array should look like n subblocks with
#     each subblock preserving the "physical" layout of arr.
#     """
#     h, w = arr.shape
#     assert h % nrows == 0, f"{h} rows is not evenly divisible by {nrows}"
#     assert w % ncols == 0, f"{w} cols is not evenly divisible by {ncols}"
#     return np.flip(np.rot90((arr.reshape(h//nrows, nrows, -1, ncols)
#                .swapaxes(1,2)
#                .reshape(-1, nrows, ncols)), axes = (1, 2)), axis = 1)


def blockshaped(arr, nrows, ncols, overlapping_5min_intervals = 12):
    """
    Return an array of shape (n, nrows, ncols) where
    n * nrows * ncols = arr.size

    If arr is a 2D array, the returned array should look like n subblocks with
    each subblock preserving the "physical" layout of arr.
    """

    h, w = arr.shape
    assert h % nrows == 0, f"{h} rows is not evenly divisible by {nrows}"
    assert w % ncols == 0, f"{w} cols is not evenly divisible by {ncols}"

    return np.flip(np.rot90((strided_axis0(arr, 24, overlap=overlapping_5min_intervals).reshape(-1, nrows, ncols)), axes = (1, 2)), axis = 1)

train_tonp = train[["Open", "High", "Low", "Close", "Volume"]]
val_tonp = val[["Open", "High", "Low", "Close", "Volume"]]
test_tonp = test[["Open", "High", "Low", "Close", "Volume"]]
train_array = train_tonp.to_numpy()
val_array = val_tonp.to_numpy()
test_array = test_tonp.to_numpy()

X_train_pre_final = blockshaped(train_array, 24, 5, overlapping_5min_intervals = 12)
X_val_pre_final = blockshaped(val_array, 24, 5, overlapping_5min_intervals = 12)
X_test_pre_final = blockshaped(test_array, 24, 5, overlapping_5min_intervals = 12)

# X_train_pre_final = blockshaped(train_array, 24, 5)
# X_val_pre_final = blockshaped(val_array, 24, 5)
# X_test_pre_final = blockshaped(test_array, 24, 5)

# %%
np.set_printoptions(edgeitems=10,linewidth=580)
X_train_pre_final[0]
# Out:
# array([[  19.81  ,   19.77  ,   19.75  ,   19.78  ,   19.78  ,   19.78  ,   19.79  ,   19.79  ,   19.75  ,   19.8027,   19.82  ,   19.8199,   19.88  ,   19.8968,   19.93  ,   19.93  ,   19.93  ,   19.93  ,   19.9417,   19.9147,   19.94  ,   19.96  ,   19.96  ,   19.96  ],
#        [  19.81  ,   19.77  ,   19.75  ,   19.78  ,   19.78  ,   19.78  ,   19.8   ,   19.79  ,   19.7703,   19.83  ,   19.82  ,   19.8199,   19.88  ,   19.9   ,   19.93  ,   19.93  ,   19.93  ,   19.93  ,   19.9417,   19.9147,   19.95  ,   19.96  ,   19.96  ,   19.96  ],
#        [  19.74  ,   19.77  ,   19.75  ,   19.78  ,   19.78  ,   19.78  ,   19.7701,   19.79  ,   19.75  ,   19.8027,   19.82  ,   19.8   ,   19.88  ,   19.8968,   19.92  ,   19.93  ,   19.93  ,   19.93  ,   19.94  ,   19.9147,   19.94  ,   19.9301,   19.96  ,   19.96  ],
#        [  19.77  ,   19.77  ,   19.75  ,   19.78  ,   19.78  ,   19.78  ,   19.7776,   19.79  ,   19.7703,   19.83  ,   19.82  ,   19.8   ,   19.88  ,   19.9   ,   19.93  ,   19.93  ,   19.93  ,   19.93  ,   19.94  ,   19.9147,   19.95  ,   19.9594,   19.96  ,   19.96  ],
#        [1066.    ,  142.    ,  344.    ,  355.    ,    0.    ,    0.    , 2800.    ,  400.    , 6100.    ,  300.    ,  400.    ,  300.    ,    0.    , 3000.    , 2085.    ,  585.    ,    0.    ,    0.    , 1950.    ,  200.    , 1025.    ,  826.    ,  200.    ,    0.    ]])

# %%
train_tonp[0:24]
# Out:
#                               Open     High      Low    Close  Volume
# Time
# 2017-02-15 09:30:00-05:00  19.8100  19.8100  19.7400  19.7700  1066.0
# 2017-02-15 09:35:00-05:00  19.7700  19.7700  19.7700  19.7700   142.0
# 2017-02-15 09:40:00-05:00  19.7500  19.7500  19.7500  19.7500   344.0
# 2017-02-15 09:45:00-05:00  19.7800  19.7800  19.7800  19.7800   355.0
# 2017-02-15 09:50:00-05:00  19.7800  19.7800  19.7800  19.7800     0.0
# 2017-02-15 09:55:00-05:00  19.7800  19.7800  19.7800  19.7800     0.0
# 2017-02-15 10:00:00-05:00  19.7900  19.8000  19.7701  19.7776  2800.0
# 2017-02-15 10:05:00-05:00  19.7900  19.7900  19.7900  19.7900   400.0
# 2017-02-15 10:10:00-05:00  19.7500  19.7703  19.7500  19.7703  6100.0
# 2017-02-15 10:15:00-05:00  19.8027  19.8300  19.8027  19.8300   300.0
# 2017-02-15 10:20:00-05:00  19.8200  19.8200  19.8200  19.8200   400.0
# 2017-02-15 10:25:00-05:00  19.8199  19.8199  19.8000  19.8000   300.0
# 2017-02-15 10:30:00-05:00  19.8800  19.8800  19.8800  19.8800     0.0
# 2017-02-15 10:35:00-05:00  19.8968  19.9000  19.8968  19.9000  3000.0
# 2017-02-15 10:40:00-05:00  19.9300  19.9300  19.9200  19.9300  2085.0
# 2017-02-15 10:45:00-05:00  19.9300  19.9300  19.9300  19.9300   585.0
# 2017-02-15 10:50:00-05:00  19.9300  19.9300  19.9300  19.9300     0.0
# 2017-02-15 10:55:00-05:00  19.9300  19.9300  19.9300  19.9300     0.0
# 2017-02-15 11:00:00-05:00  19.9417  19.9417  19.9400  19.9400  1950.0
# 2017-02-15 11:05:00-05:00  19.9147  19.9147  19.9147  19.9147   200.0
# 2017-02-15 11:10:00-05:00  19.9400  19.9500  19.9400  19.9500  1025.0
# 2017-02-15 11:15:00-05:00  19.9600  19.9600  19.9301  19.9594   826.0
# 2017-02-15 11:20:00-05:00  19.9600  19.9600  19.9600  19.9600   200.0
# 2017-02-15 11:25:00-05:00  19.9600  19.9600  19.9600  19.9600     0.0

# %%
X_train_pre_final[1]
# Out:
# array([[  19.88  ,   19.8968,   19.93  ,   19.93  ,   19.93  ,   19.93  ,   19.9417,   19.9147,   19.94  ,   19.96  ,   19.96  ,   19.96  ,   19.9564,   19.9564,   19.9564,   19.95  ,   19.96  ,   19.9598,   19.96  ,   19.9931,   20.01  ,   20.01  ,   19.97  ,   19.989 ],
#        [  19.88  ,   19.9   ,   19.93  ,   19.93  ,   19.93  ,   19.93  ,   19.9417,   19.9147,   19.95  ,   19.96  ,   19.96  ,   19.96  ,   19.9564,   19.9564,   19.9564,   19.95  ,   19.96  ,   19.9598,   19.99  ,   20.0179,   20.01  ,   20.01  ,   19.97  ,   19.99  ],
#        [  19.88  ,   19.8968,   19.92  ,   19.93  ,   19.93  ,   19.93  ,   19.94  ,   19.9147,   19.94  ,   19.9301,   19.96  ,   19.96  ,   19.9564,   19.9564,   19.9564,   19.95  ,   19.95  ,   19.9598,   19.96  ,   19.9931,   20.01  ,   20.01  ,   19.9696,   19.984 ],
#        [  19.88  ,   19.9   ,   19.93  ,   19.93  ,   19.93  ,   19.93  ,   19.94  ,   19.9147,   19.95  ,   19.9594,   19.96  ,   19.96  ,   19.9564,   19.9564,   19.9564,   19.95  ,   19.9599,   19.9598,   19.99  ,   20.01  ,   20.01  ,   20.01  ,   19.9696,   19.99  ],
#        [   0.    , 3000.    , 2085.    ,  585.    ,    0.    ,    0.    , 1950.    ,  200.    , 1025.    ,  826.    ,  200.    ,    0.    ,  455.    ,    0.    ,    0.    , 1000.    , 1250.    ,  100.    , 1675.    , 3635.    ,    0.    ,    0.    , 1720.    , 1898.    ]])

# %%
# create target from OHLC and Volume Data
###### THIS IS FOR 3 CLASS FROM PAPER ########
# def buildTargets(obs_array,  
#                  alph = .55, 
#                  volity_int = 10):

#   """ 
#   This function will take a complete set of train, val, and test 
#   data and return the targets. Volitility will be calculated over 
#   the 24 5min incriments. The Target shift is looking at 2 hours 
#   shift from current time

#   shift_2hour = The amount of time the data interval take to equal 2 hours 
#                 (i.e. 5 min data interval is equal to 24)
#   alph = The alpha value for calculating the shift in price
#   volity_int = the number of incriments used to calculate volitility 
#   """

#   target_close_list =[]

#   for arr in obs_array:
#     target_close_list.append(arr[3][-1])
  
#   target_close_df = pd.DataFrame()
#   target_close_df["Close"] = target_close_list

#   target_close_df["Volitility"] = target_close_df["Close"].rolling(volity_int).std()

#   # print(len(volatility), len(target_close_df["Close"]))

  
#   targets = [0] * len(target_close_df.Close)

#   targets = np.where(target_close_df.Close.shift() >= (target_close_df.Close * (1 + alph * target_close_df["Volitility"])), 
#            2, targets)
  
#   targets = np.where(target_close_df.Close.shift() <= (target_close_df.Close * (1 - alph * target_close_df["Volitility"])), 
#            1, targets)

#   return targets


#####DISREGUARD THE VOLITLITY######
def buildTargets(obs_array,  
                 alph = .55, 
                 volity_int = 10):

  """ 
  This function will take a complete set of train, val, and test 
  data and return the targets. Volitility will be calculated over 
  the 24 5min incriments. The Target shift is looking at 2 hours 
  shift from current time

  shift_2hour = The amount of time the data interval take to equal 2 hours 
                (i.e. 5 min data interval is equal to 24)
  alph = The alpha value for calculating the shift in price
  volity_int = the number of incriments used to calculate volitility 
  """

  target_close_list =[]

  for arr in obs_array:
    target_close_list.append(arr[3][-1])
  
  target_close_df = pd.DataFrame()
  target_close_df["Close"] = target_close_list

  target_close_df["Volitility"] = target_close_df["Close"].rolling(volity_int).std()

  # print(len(volatility), len(target_close_df["Close"]))

  
  targets = [0] * len(target_close_df.Close)

  targets = np.where(target_close_df.Close.shift() >= (target_close_df.Close * (1 + alph)), 
           2, targets)
  
  targets = np.where(target_close_df.Close.shift() <= (target_close_df.Close * (1 - alph)), 
           1, targets)

  return targets

  #####Binary Class######
# def buildTargets(obs_array,  
#                  alph = .55, 
#                  volity_int = 10):

#   """ 
#   This function will take a complete set of train, val, and test 
#   data and return the targets. Volitility will be calculated over 
#   the 24 5min incriments. The Target shift is looking at 2 hours 
#   shift from current time

#   shift_2hour = The amount of time the data interval take to equal 2 hours 
#                 (i.e. 5 min data interval is equal to 24)
#   alph = The alpha value for calculating the shift in price
#   volity_int = the number of incriments used to calculate volitility 
#   """

#   target_close_list =[]

#   for arr in obs_array:
#     target_close_list.append(arr[3][-1])
  
#   target_close_df = pd.DataFrame()
#   target_close_df["Close"] = target_close_list

#   target_close_df["Volitility"] = target_close_df["Close"].rolling(volity_int).std()

#   # print(len(volatility), len(target_close_df["Close"]))

  
#   targets = [0] * len(target_close_df.Close)

#   targets = np.where(target_close_df.Close.shift() >= (target_close_df.Close * (1 + alph)), 
#            1, targets)

#   return targets

# %%
volity_val = 10
alph = .001
y_train_pre_final = buildTargets(X_train_pre_final, alph=alph,  volity_int = volity_val)
y_val_pre_final = buildTargets(X_val_pre_final, alph=alph, volity_int = volity_val)
y_test_pre_final = buildTargets(X_test_pre_final, alph=alph, volity_int = volity_val)

# %%
def get_class_distribution(obj):
    count_dict = {
        "up": 0,
        "flat": 0,
        "down": 0,
    }
    
    for i in obj:
        if i == 2: 
            count_dict['up'] += 1
        elif i == 1: 
            count_dict['down'] += 1
        elif i == 0: 
            count_dict['flat'] += 1             
        else:
            print("Check classes.")
            
    return count_dict

# %%
bfig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25,7))
# Train
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_train_pre_final)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[0]).set_title('Class Distribution in Train Set')
# Validation
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_val_pre_final)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[1]).set_title('Class Distribution in Val Set')
# Test
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_test_pre_final)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[2]).set_title('Class Distribution in Test Set')
# Out:
# Text(0.5, 1.0, 'Class Distribution in Test Set')

# %%
def createFinalData_RemoveLateAfternoonData(arr, labels):

  assert arr.shape[0] == len(labels), "X data do not match length of y labels"

  step_count = 0
  filtered_y_labels = []

  for i in range(arr.shape[0]):

    if i == 0:
      final_arr = arr[i]
      filtered_y_labels.append(labels[i])
      #print(f'Appending index {i}, step_count: {step_count}')
      step_count += 1

    elif i == 1:

      final_arr = np.stack((final_arr, arr[i]))
      filtered_y_labels.append(labels[i])
      step_count += 1

    elif step_count == 0: 
      final_arr = np.vstack((final_arr, arr[i][None]))
      filtered_y_labels.append(labels[i])
      #print(f'Appending index {i}, step_count: {step_count}')
      step_count += 1
    
    elif (step_count) % 5 == 0:
      #print(f'skipping {i} array, step_count: {step_count}')
      step_count += 1

    elif (step_count) % 6 == 0:
      #print(f'skipping {i} array, step_count: {step_count}')
      step_count += 1

    elif (step_count) % 7 == 0:
      #print(f'skipping {i} array, step_count: {step_count}')
      step_count = 0
    
    else:
      final_arr = np.vstack((final_arr, arr[i][None]))
      filtered_y_labels.append(labels[i])
      #print(f'Appending index {i}, step_count: {step_count}')
      step_count += 1
  
  return final_arr, filtered_y_labels

X_train, y_train = createFinalData_RemoveLateAfternoonData(X_train_pre_final, y_train_pre_final)
X_val, y_val = createFinalData_RemoveLateAfternoonData(X_val_pre_final, y_val_pre_final)
X_test, y_test = createFinalData_RemoveLateAfternoonData(X_test_pre_final, y_test_pre_final)

y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %%
# Check it arrays are made correctly
train[12:48]
# Out:
#                               Open     High  ...  Volume  VolumeWeightedAvgPrice
# Time                                         ...
# 2017-02-15 10:30:00-05:00  19.8800  19.8800  ...     0.0               19.876667
# 2017-02-15 10:35:00-05:00  19.8968  19.9000  ...  3000.0               19.899467
# 2017-02-15 10:40:00-05:00  19.9300  19.9300  ...  2085.0               19.925175
# 2017-02-15 10:45:00-05:00  19.9300  19.9300  ...   585.0               19.930000
# 2017-02-15 10:50:00-05:00  19.9300  19.9300  ...     0.0                0.000000
# 2017-02-15 10:55:00-05:00  19.9300  19.9300  ...     0.0                0.000000
# 2017-02-15 11:00:00-05:00  19.9417  19.9417  ...  1950.0               19.941569
# 2017-02-15 11:05:00-05:00  19.9147  19.9147  ...   200.0               19.914700
# 2017-02-15 11:10:00-05:00  19.9400  19.9500  ...  1025.0               19.945854
# 2017-02-15 11:15:00-05:00  19.9600  19.9600  ...   826.0               19.953904
# 2017-02-15 11:20:00-05:00  19.9600  19.9600  ...   200.0               19.960000
# 2017-02-15 11:25:00-05:00  19.9600  19.9600  ...     0.0                0.000000
# 2017-02-15 11:30:00-05:00  19.9564  19.9564  ...   455.0               19.956297
# 2017-02-15 11:35:00-05:00  19.9564  19.9564  ...     0.0                0.000000
# 2017-02-15 11:40:00-05:00  19.9564  19.9564  ...     0.0                0.000000
# 2017-02-15 11:45:00-05:00  19.9500  19.9500  ...  1000.0               19.950000
# 2017-02-15 11:50:00-05:00  19.9600  19.9600  ...  1250.0               19.954384
# 2017-02-15 11:55:00-05:00  19.9598  19.9598  ...   100.0               19.959800
# 2017-02-15 12:00:00-05:00  19.9600  19.9900  ...  1675.0               19.985490
# 2017-02-15 12:05:00-05:00  19.9931  20.0179  ...  3635.0               19.998988
# 2017-02-15 12:10:00-05:00  20.0100  20.0100  ...     0.0                0.000000
# 2017-02-15 12:15:00-05:00  20.0100  20.0100  ...     0.0                0.000000
# 2017-02-15 12:20:00-05:00  19.9700  19.9700  ...  1720.0               19.969693
# 2017-02-15 12:25:00-05:00  19.9890  19.9900  ...  1898.0               19.988262
# 2017-02-15 12:30:00-05:00  19.9900  19.9900  ...     0.0                0.000000
# 2017-02-15 12:35:00-05:00  20.0100  20.0400  ...   500.0               20.032000
# 2017-02-15 12:40:00-05:00  20.0400  20.0500  ...  1581.0               20.035066
# 2017-02-15 12:45:00-05:00  20.0500  20.0500  ...     0.0                0.000000
# 2017-02-15 12:50:00-05:00  20.0500  20.0500  ...     0.0                0.000000
# 2017-02-15 12:55:00-05:00  20.0500  20.0500  ...   100.0               20.050000
# 2017-02-15 13:00:00-05:00  20.0498  20.0498  ...   187.0               20.049800
# 2017-02-15 13:05:00-05:00  20.0394  20.0500  ...  1900.0               20.041105
# 2017-02-15 13:10:00-05:00  20.0300  20.0300  ...   800.0               20.027300
# 2017-02-15 13:15:00-05:00  20.0300  20.0300  ...  1894.0               20.022437
# 2017-02-15 13:20:00-05:00  20.0227  20.0227  ...     0.0                0.000000
# 2017-02-15 13:25:00-05:00  20.0227  20.0227  ...     0.0                0.000000
#
# [36 rows x 6 columns]

# %%
np.set_printoptions(threshold=200)
y_train_pre_final[50:75]
# Out:
# array([2, 2, 0, 1, 0, 2, 0, 0, 2, 1, 0, 0, 0, 2, 2, 2, 0, 1, 0, 0, 0, 1, 2, 1, 2])

# %%
######
# Code fro scaling at a later date
######

# from sklearn.preprocessing import MinMaxScaler

from sklearn.preprocessing import StandardScaler

scalers = {}
for i in range(X_train.shape[1]):
    scalers[i] = StandardScaler()
    X_train[:, i, :] = scalers[i].fit_transform(X_train[:, i, :]) 

for i in range(X_val.shape[1]):
    X_val[:, i, :] = scalers[i].fit_transform(X_val[:, i, :]) 

for i in range(X_test.shape[1]):
    X_test[:, i, :] = scalers[i].fit_transform(X_test[:, i, :])

# %%
def get_class_distribution(obj):
    count_dict = {
        "up": 0,
        "flat": 0,
        "down": 0,
    }
    
    for i in obj:
        if i == 2: 
            count_dict['up'] += 1
        elif i == 1: 
            count_dict['down'] += 1
        elif i == 0: 
            count_dict['flat'] += 1             
        else:
            print("Check classes.")
            
    return count_dict

# %%
bfig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25,7))
# Train
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_train)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[0]).set_title('Class Distribution in Train Set')
# Validation
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_val)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[1]).set_title('Class Distribution in Val Set')
# Test
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_test)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[2]).set_title('Class Distribution in Test Set')
# Out:
# Text(0.5, 1.0, 'Class Distribution in Test Set')

# %%
###### ONLY EXECUTE FOR 2D CNN #####

# X_train = X_train.reshape(X_train.shape[0], 
#                           X_train.shape[1], 
#                           X_train.shape[2],
#                           1)
# X_val = X_val.reshape(X_val.shape[0],
#                           X_val.shape[1], 
#                           X_val.shape[2],
#                           1)
# X_test = X_test.reshape(X_test.shape[0],
#                           X_test.shape[1], 
#                           X_test.shape[2],
#                           1)

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train, 3)
y_val = to_categorical(y_val, 3)
y_test = to_categorical(y_test, 3)

# %%
print(f'X Train Length {X_train.shape}, y Train Label Length {y_train.shape}')
print(f'X Val Length {X_val.shape}, y Val Label Length {y_val.shape}')
print(f'X Test Length {X_test.shape}, y Test Label Length {y_test.shape}')
# Out:
# X Train Length (4065, 5, 24), y Train Label Length (4065, 3)
# X Val Length (1425, 5, 24), y Val Label Length (1425, 3)
# X Test Length (1040, 5, 24), y Test Label Length (1040, 3)

# %% [markdown]
# # KERAS 1D Model

# %%
import tensorflow as tf
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.optimizers import Adam, Nadam

# %%
# Simple Model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=(X_train.shape[1],X_train.shape[2])))
model.add(MaxPooling1D(pool_size=3, strides=1, padding='same'))
model.add(Dropout(0.7))
model.add(Conv1D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
model.add(Dropout(0.7))
model.add(Flatten())
model.add(Dense(1000,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(3,activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 5, 32)             2336
#
#  max_pooling1d (MaxPooling1D  (None, 5, 32)            0
#  )
#
#  dropout (Dropout)           (None, 5, 32)             0
#
#  conv1d_1 (Conv1D)           (None, 5, 64)             6208
#
#  max_pooling1d_1 (MaxPooling  (None, 3, 64)            0
#  1D)
#
#  dropout_1 (Dropout)         (None, 3, 64)             0
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 1000)              193000
#
#  dense_1 (Dense)             (None, 500)               500500
#
#  dense_2 (Dense)             (None, 3)                 1503
#
# =================================================================
# Total params: 703,547
# Trainable params: 703,547
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(learning_rate=0.001, decay=0.0001)
nadam = Nadam(learning_rate=0.002, beta_1=0.9, beta_2=0.999, epsilon=1e-08, schedule_decay=0.004)

def custom_loss_function(y_true, y_pred):
   squared_difference = tf.square(y_true - y_pred)
   return tf.reduce_mean(squared_difference, axis=-1)

model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=["accuracy"])

# %%
batch_size = 12
hist = model.fit(X_train, y_train, batch_size=batch_size, epochs=500, validation_data=(X_val, y_val)) #, class_weight={0:1, 1:1.5})
# Out:
# Epoch 1/500
# 339/339 [==============================] - 3s 8ms/step - loss: 0.6338 - accuracy: 0.7321 - val_loss: 1.1836 - val_accuracy: 0.5312
# Epoch 2/500
# 339/339 [==============================] - 2s 7ms/step - loss: 0.6358 - accuracy: 0.7439 - val_loss: 1.2493 - val_accuracy: 0.5144
# Epoch 3/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6320 - accuracy: 0.7328 - val_loss: 1.1453 - val_accuracy: 0.5354
# Epoch 4/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6422 - accuracy: 0.7250 - val_loss: 1.1982 - val_accuracy: 0.5298
# Epoch 5/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6218 - accuracy: 0.7405 - val_loss: 1.2774 - val_accuracy: 0.4828
# Epoch 6/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6323 - accuracy: 0.7368 - val_loss: 1.1870 - val_accuracy: 0.5298
# Epoch 7/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6424 - accuracy: 0.7319 - val_loss: 1.1958 - val_accuracy: 0.5207
# Epoch 8/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.6254 - accuracy: 0.7314 - val_loss: 1.1861 - val_accuracy: 0.5333
# Epoch 9/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6268 - accuracy: 0.7392 - val_loss: 1.3021 - val_accuracy: 0.4723
# Epoch 10/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6185 - accuracy: 0.7429 - val_loss: 1.1505 - val_accuracy: 0.5368
# Epoch 11/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6327 - accuracy: 0.7294 - val_loss: 1.2186 - val_accuracy: 0.5361
# Epoch 12/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6267 - accuracy: 0.7437 - val_loss: 1.2459 - val_accuracy: 0.5186
# Epoch 13/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6150 - accuracy: 0.7314 - val_loss: 1.2536 - val_accuracy: 0.5158
# Epoch 14/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6105 - accuracy: 0.7385 - val_loss: 1.2520 - val_accuracy: 0.5123
# Epoch 15/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6361 - accuracy: 0.7360 - val_loss: 1.2421 - val_accuracy: 0.5347
# Epoch 16/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6150 - accuracy: 0.7353 - val_loss: 1.2202 - val_accuracy: 0.5256
# Epoch 17/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6243 - accuracy: 0.7380 - val_loss: 1.3038 - val_accuracy: 0.5032
# Epoch 18/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.6317 - accuracy: 0.7301 - val_loss: 1.2496 - val_accuracy: 0.5130
# Epoch 19/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6225 - accuracy: 0.7437 - val_loss: 1.1997 - val_accuracy: 0.5207
# Epoch 20/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6306 - accuracy: 0.7378 - val_loss: 1.2042 - val_accuracy: 0.5179
# Epoch 21/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6193 - accuracy: 0.7439 - val_loss: 1.2075 - val_accuracy: 0.5277
# Epoch 22/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.6290 - accuracy: 0.7311 - val_loss: 1.1840 - val_accuracy: 0.5193
# Epoch 23/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6290 - accuracy: 0.7397 - val_loss: 1.2159 - val_accuracy: 0.5256
# Epoch 24/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6018 - accuracy: 0.7501 - val_loss: 1.2337 - val_accuracy: 0.5158
# Epoch 25/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.6067 - accuracy: 0.7518 - val_loss: 1.2274 - val_accuracy: 0.5263
# Epoch 26/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.6068 - accuracy: 0.7474 - val_loss: 1.2295 - val_accuracy: 0.5305
# Epoch 27/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6133 - accuracy: 0.7412 - val_loss: 1.1663 - val_accuracy: 0.5284
# Epoch 28/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6176 - accuracy: 0.7461 - val_loss: 1.2489 - val_accuracy: 0.5249
# Epoch 29/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6172 - accuracy: 0.7488 - val_loss: 1.1869 - val_accuracy: 0.5347
# Epoch 30/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6151 - accuracy: 0.7437 - val_loss: 1.1657 - val_accuracy: 0.5411
# Epoch 31/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6063 - accuracy: 0.7501 - val_loss: 1.2172 - val_accuracy: 0.5432
# Epoch 32/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6118 - accuracy: 0.7469 - val_loss: 1.2371 - val_accuracy: 0.5228
# Epoch 33/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6229 - accuracy: 0.7422 - val_loss: 1.2739 - val_accuracy: 0.5186
# Epoch 34/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5949 - accuracy: 0.7525 - val_loss: 1.1938 - val_accuracy: 0.5425
# Epoch 35/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5958 - accuracy: 0.7530 - val_loss: 1.2334 - val_accuracy: 0.5312
# Epoch 36/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6071 - accuracy: 0.7432 - val_loss: 1.2051 - val_accuracy: 0.5305
# Epoch 37/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.6116 - accuracy: 0.7429 - val_loss: 1.1979 - val_accuracy: 0.5333
# Epoch 38/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5990 - accuracy: 0.7491 - val_loss: 1.2188 - val_accuracy: 0.5404
# Epoch 39/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6022 - accuracy: 0.7518 - val_loss: 1.3124 - val_accuracy: 0.5179
# Epoch 40/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6160 - accuracy: 0.7405 - val_loss: 1.2128 - val_accuracy: 0.5291
# Epoch 41/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6011 - accuracy: 0.7432 - val_loss: 1.2841 - val_accuracy: 0.5193
# Epoch 42/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.6022 - accuracy: 0.7501 - val_loss: 1.2893 - val_accuracy: 0.5347
# Epoch 43/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6146 - accuracy: 0.7469 - val_loss: 1.2995 - val_accuracy: 0.5221
# Epoch 44/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6077 - accuracy: 0.7456 - val_loss: 1.2131 - val_accuracy: 0.5347
# Epoch 45/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6271 - accuracy: 0.7378 - val_loss: 1.2858 - val_accuracy: 0.5144
# Epoch 46/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5919 - accuracy: 0.7424 - val_loss: 1.2378 - val_accuracy: 0.5200
# Epoch 47/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5973 - accuracy: 0.7478 - val_loss: 1.3143 - val_accuracy: 0.5130
# Epoch 48/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5939 - accuracy: 0.7496 - val_loss: 1.2158 - val_accuracy: 0.5256
# Epoch 49/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5948 - accuracy: 0.7542 - val_loss: 1.2650 - val_accuracy: 0.5256
# Epoch 50/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5938 - accuracy: 0.7518 - val_loss: 1.3162 - val_accuracy: 0.5179
# Epoch 51/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6015 - accuracy: 0.7493 - val_loss: 1.2595 - val_accuracy: 0.5221
# Epoch 52/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6048 - accuracy: 0.7383 - val_loss: 1.2577 - val_accuracy: 0.5396
# Epoch 53/500
# 339/339 [==============================] - 2s 6ms/step - loss: 0.5854 - accuracy: 0.7525 - val_loss: 1.3218 - val_accuracy: 0.5256
# Epoch 54/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5964 - accuracy: 0.7557 - val_loss: 1.3201 - val_accuracy: 0.5263
# Epoch 55/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5926 - accuracy: 0.7577 - val_loss: 1.2431 - val_accuracy: 0.5425
# Epoch 56/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5875 - accuracy: 0.7609 - val_loss: 1.3319 - val_accuracy: 0.5067
# Epoch 57/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5923 - accuracy: 0.7496 - val_loss: 1.2973 - val_accuracy: 0.5207
# Epoch 58/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5916 - accuracy: 0.7493 - val_loss: 1.3629 - val_accuracy: 0.5165
# Epoch 59/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6000 - accuracy: 0.7461 - val_loss: 1.3072 - val_accuracy: 0.5263
# Epoch 60/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5915 - accuracy: 0.7476 - val_loss: 1.2736 - val_accuracy: 0.5326
# Epoch 61/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5972 - accuracy: 0.7533 - val_loss: 1.3061 - val_accuracy: 0.5214
# Epoch 62/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5798 - accuracy: 0.7555 - val_loss: 1.2571 - val_accuracy: 0.5389
# Epoch 63/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6021 - accuracy: 0.7528 - val_loss: 1.2495 - val_accuracy: 0.5396
# Epoch 64/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6015 - accuracy: 0.7466 - val_loss: 1.2824 - val_accuracy: 0.5242
# Epoch 65/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5898 - accuracy: 0.7533 - val_loss: 1.2768 - val_accuracy: 0.5242
# Epoch 66/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6004 - accuracy: 0.7520 - val_loss: 1.2733 - val_accuracy: 0.5165
# Epoch 67/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5872 - accuracy: 0.7601 - val_loss: 1.3120 - val_accuracy: 0.5221
# Epoch 68/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5914 - accuracy: 0.7510 - val_loss: 1.2892 - val_accuracy: 0.5137
# Epoch 69/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5808 - accuracy: 0.7542 - val_loss: 1.3338 - val_accuracy: 0.5137
# Epoch 70/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5772 - accuracy: 0.7616 - val_loss: 1.3322 - val_accuracy: 0.5221
# Epoch 71/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.6020 - accuracy: 0.7397 - val_loss: 1.2831 - val_accuracy: 0.5404
# Epoch 72/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5919 - accuracy: 0.7560 - val_loss: 1.3209 - val_accuracy: 0.5158
# Epoch 73/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5909 - accuracy: 0.7510 - val_loss: 1.3119 - val_accuracy: 0.5200
# Epoch 74/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5893 - accuracy: 0.7626 - val_loss: 1.3168 - val_accuracy: 0.5347
# Epoch 75/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5999 - accuracy: 0.7483 - val_loss: 1.2859 - val_accuracy: 0.5130
# Epoch 76/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5839 - accuracy: 0.7552 - val_loss: 1.3130 - val_accuracy: 0.5165
# Epoch 77/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6009 - accuracy: 0.7565 - val_loss: 1.2869 - val_accuracy: 0.5172
# Epoch 78/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5983 - accuracy: 0.7540 - val_loss: 1.3735 - val_accuracy: 0.5067
# Epoch 79/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5911 - accuracy: 0.7560 - val_loss: 1.3398 - val_accuracy: 0.5179
# Epoch 80/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5856 - accuracy: 0.7562 - val_loss: 1.3099 - val_accuracy: 0.5130
# Epoch 81/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5817 - accuracy: 0.7621 - val_loss: 1.3389 - val_accuracy: 0.5172
# Epoch 82/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5871 - accuracy: 0.7604 - val_loss: 1.3334 - val_accuracy: 0.5235
# Epoch 83/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5946 - accuracy: 0.7569 - val_loss: 1.3389 - val_accuracy: 0.5214
# Epoch 84/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5880 - accuracy: 0.7545 - val_loss: 1.3424 - val_accuracy: 0.5123
# Epoch 85/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5792 - accuracy: 0.7589 - val_loss: 1.4079 - val_accuracy: 0.4989
# Epoch 86/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5806 - accuracy: 0.7560 - val_loss: 1.2988 - val_accuracy: 0.5284
# Epoch 87/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5852 - accuracy: 0.7520 - val_loss: 1.3287 - val_accuracy: 0.5270
# Epoch 88/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5866 - accuracy: 0.7594 - val_loss: 1.3741 - val_accuracy: 0.5053
# Epoch 89/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5696 - accuracy: 0.7661 - val_loss: 1.3329 - val_accuracy: 0.5158
# Epoch 90/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5912 - accuracy: 0.7550 - val_loss: 1.2993 - val_accuracy: 0.5305
# Epoch 91/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5779 - accuracy: 0.7606 - val_loss: 1.3575 - val_accuracy: 0.5158
# Epoch 92/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5654 - accuracy: 0.7658 - val_loss: 1.3480 - val_accuracy: 0.5221
# Epoch 93/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5917 - accuracy: 0.7513 - val_loss: 1.3127 - val_accuracy: 0.5235
# Epoch 94/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5794 - accuracy: 0.7569 - val_loss: 1.2637 - val_accuracy: 0.5340
# Epoch 95/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5724 - accuracy: 0.7614 - val_loss: 1.3314 - val_accuracy: 0.5151
# Epoch 96/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5769 - accuracy: 0.7572 - val_loss: 1.3367 - val_accuracy: 0.5109
# Epoch 97/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5721 - accuracy: 0.7638 - val_loss: 1.3647 - val_accuracy: 0.5235
# Epoch 98/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.6017 - accuracy: 0.7469 - val_loss: 1.3504 - val_accuracy: 0.5095
# Epoch 99/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5667 - accuracy: 0.7641 - val_loss: 1.2989 - val_accuracy: 0.5312
# Epoch 100/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5876 - accuracy: 0.7567 - val_loss: 1.3478 - val_accuracy: 0.5214
# Epoch 101/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5858 - accuracy: 0.7636 - val_loss: 1.3251 - val_accuracy: 0.5305
# Epoch 102/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5630 - accuracy: 0.7641 - val_loss: 1.4487 - val_accuracy: 0.5095
# Epoch 103/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5734 - accuracy: 0.7702 - val_loss: 1.3143 - val_accuracy: 0.5242
# Epoch 104/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5819 - accuracy: 0.7582 - val_loss: 1.3128 - val_accuracy: 0.5214
# Epoch 105/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5789 - accuracy: 0.7633 - val_loss: 1.2761 - val_accuracy: 0.5319
# Epoch 106/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5797 - accuracy: 0.7616 - val_loss: 1.4213 - val_accuracy: 0.5032
# Epoch 107/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5718 - accuracy: 0.7643 - val_loss: 1.3427 - val_accuracy: 0.5165
# Epoch 108/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5697 - accuracy: 0.7638 - val_loss: 1.3475 - val_accuracy: 0.5137
# Epoch 109/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5682 - accuracy: 0.7685 - val_loss: 1.4045 - val_accuracy: 0.4968
# Epoch 110/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5701 - accuracy: 0.7683 - val_loss: 1.3531 - val_accuracy: 0.5102
# Epoch 111/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5776 - accuracy: 0.7589 - val_loss: 1.3690 - val_accuracy: 0.5235
# Epoch 112/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5686 - accuracy: 0.7601 - val_loss: 1.3967 - val_accuracy: 0.5228
# Epoch 113/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5690 - accuracy: 0.7633 - val_loss: 1.4012 - val_accuracy: 0.5116
# Epoch 114/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5624 - accuracy: 0.7744 - val_loss: 1.3309 - val_accuracy: 0.5270
# Epoch 115/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.6046 - accuracy: 0.7483 - val_loss: 1.3260 - val_accuracy: 0.5249
# Epoch 116/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5793 - accuracy: 0.7619 - val_loss: 1.3211 - val_accuracy: 0.5284
# Epoch 117/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5834 - accuracy: 0.7528 - val_loss: 1.3301 - val_accuracy: 0.5207
# Epoch 118/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5736 - accuracy: 0.7673 - val_loss: 1.3285 - val_accuracy: 0.5277
# Epoch 119/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5610 - accuracy: 0.7717 - val_loss: 1.3789 - val_accuracy: 0.5256
# Epoch 120/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5832 - accuracy: 0.7562 - val_loss: 1.3011 - val_accuracy: 0.5270
# Epoch 121/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5647 - accuracy: 0.7678 - val_loss: 1.3492 - val_accuracy: 0.5221
# Epoch 122/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5590 - accuracy: 0.7668 - val_loss: 1.3354 - val_accuracy: 0.5200
# Epoch 123/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5686 - accuracy: 0.7641 - val_loss: 1.3854 - val_accuracy: 0.5109
# Epoch 124/500
# 339/339 [==============================] - 2s 7ms/step - loss: 0.5650 - accuracy: 0.7646 - val_loss: 1.3684 - val_accuracy: 0.5158
# Epoch 125/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5769 - accuracy: 0.7626 - val_loss: 1.3897 - val_accuracy: 0.5123
# Epoch 126/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5747 - accuracy: 0.7656 - val_loss: 1.3566 - val_accuracy: 0.5144
# Epoch 127/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5814 - accuracy: 0.7663 - val_loss: 1.3590 - val_accuracy: 0.5130
# Epoch 128/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5731 - accuracy: 0.7680 - val_loss: 1.4149 - val_accuracy: 0.5039
# Epoch 129/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5771 - accuracy: 0.7624 - val_loss: 1.4061 - val_accuracy: 0.5123
# Epoch 130/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5595 - accuracy: 0.7764 - val_loss: 1.3697 - val_accuracy: 0.5137
# Epoch 131/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5689 - accuracy: 0.7621 - val_loss: 1.3762 - val_accuracy: 0.5305
# Epoch 132/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5676 - accuracy: 0.7656 - val_loss: 1.4035 - val_accuracy: 0.5081
# Epoch 133/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5659 - accuracy: 0.7690 - val_loss: 1.4079 - val_accuracy: 0.5088
# Epoch 134/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5460 - accuracy: 0.7742 - val_loss: 1.4141 - val_accuracy: 0.5179
# Epoch 135/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5628 - accuracy: 0.7697 - val_loss: 1.3898 - val_accuracy: 0.5151
# Epoch 136/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5637 - accuracy: 0.7641 - val_loss: 1.4033 - val_accuracy: 0.5207
# Epoch 137/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5531 - accuracy: 0.7707 - val_loss: 1.4349 - val_accuracy: 0.5172
# Epoch 138/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5680 - accuracy: 0.7599 - val_loss: 1.4180 - val_accuracy: 0.5221
# Epoch 139/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5575 - accuracy: 0.7700 - val_loss: 1.3937 - val_accuracy: 0.5130
# Epoch 140/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5540 - accuracy: 0.7688 - val_loss: 1.4043 - val_accuracy: 0.5123
# Epoch 141/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5567 - accuracy: 0.7646 - val_loss: 1.4319 - val_accuracy: 0.5095
# Epoch 142/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5770 - accuracy: 0.7638 - val_loss: 1.4115 - val_accuracy: 0.5130
# Epoch 143/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5439 - accuracy: 0.7766 - val_loss: 1.4482 - val_accuracy: 0.5004
# Epoch 144/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5736 - accuracy: 0.7624 - val_loss: 1.3679 - val_accuracy: 0.5144
# Epoch 145/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5592 - accuracy: 0.7680 - val_loss: 1.4161 - val_accuracy: 0.5046
# Epoch 146/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5576 - accuracy: 0.7752 - val_loss: 1.4571 - val_accuracy: 0.5130
# Epoch 147/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5537 - accuracy: 0.7734 - val_loss: 1.4169 - val_accuracy: 0.5172
# Epoch 148/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5658 - accuracy: 0.7678 - val_loss: 1.4809 - val_accuracy: 0.5032
# Epoch 149/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5608 - accuracy: 0.7695 - val_loss: 1.4470 - val_accuracy: 0.5060
# Epoch 150/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5631 - accuracy: 0.7673 - val_loss: 1.3506 - val_accuracy: 0.5221
# Epoch 151/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5751 - accuracy: 0.7675 - val_loss: 1.4231 - val_accuracy: 0.5137
# Epoch 152/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5552 - accuracy: 0.7766 - val_loss: 1.3674 - val_accuracy: 0.5144
# Epoch 153/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5661 - accuracy: 0.7690 - val_loss: 1.4666 - val_accuracy: 0.5053
# Epoch 154/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5529 - accuracy: 0.7702 - val_loss: 1.4346 - val_accuracy: 0.5200
# Epoch 155/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5552 - accuracy: 0.7727 - val_loss: 1.4537 - val_accuracy: 0.5004
# Epoch 156/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5631 - accuracy: 0.7629 - val_loss: 1.4610 - val_accuracy: 0.5004
# Epoch 157/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5535 - accuracy: 0.7749 - val_loss: 1.4221 - val_accuracy: 0.5109
# Epoch 158/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5588 - accuracy: 0.7710 - val_loss: 1.4017 - val_accuracy: 0.5158
# Epoch 159/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5683 - accuracy: 0.7629 - val_loss: 1.3925 - val_accuracy: 0.5186
# Epoch 160/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5581 - accuracy: 0.7700 - val_loss: 1.3927 - val_accuracy: 0.5130
# Epoch 161/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5429 - accuracy: 0.7786 - val_loss: 1.3995 - val_accuracy: 0.5200
# Epoch 162/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5489 - accuracy: 0.7724 - val_loss: 1.3968 - val_accuracy: 0.5214
# Epoch 163/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5662 - accuracy: 0.7636 - val_loss: 1.3595 - val_accuracy: 0.5277
# Epoch 164/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5488 - accuracy: 0.7806 - val_loss: 1.4102 - val_accuracy: 0.5186
# Epoch 165/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5701 - accuracy: 0.7658 - val_loss: 1.4117 - val_accuracy: 0.5151
# Epoch 166/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5584 - accuracy: 0.7712 - val_loss: 1.4679 - val_accuracy: 0.5032
# Epoch 167/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5485 - accuracy: 0.7761 - val_loss: 1.4643 - val_accuracy: 0.5151
# Epoch 168/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5698 - accuracy: 0.7565 - val_loss: 1.4319 - val_accuracy: 0.5067
# Epoch 169/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5642 - accuracy: 0.7656 - val_loss: 1.4520 - val_accuracy: 0.5116
# Epoch 170/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5526 - accuracy: 0.7759 - val_loss: 1.4298 - val_accuracy: 0.5186
# Epoch 171/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5624 - accuracy: 0.7683 - val_loss: 1.4401 - val_accuracy: 0.5046
# Epoch 172/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5568 - accuracy: 0.7752 - val_loss: 1.4297 - val_accuracy: 0.5109
# Epoch 173/500
# 339/339 [==============================] - 2s 7ms/step - loss: 0.5441 - accuracy: 0.7813 - val_loss: 1.4225 - val_accuracy: 0.5088
# Epoch 174/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5485 - accuracy: 0.7678 - val_loss: 1.4589 - val_accuracy: 0.5046
# Epoch 175/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5652 - accuracy: 0.7705 - val_loss: 1.4325 - val_accuracy: 0.5256
# Epoch 176/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5648 - accuracy: 0.7695 - val_loss: 1.4763 - val_accuracy: 0.5060
# Epoch 177/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5700 - accuracy: 0.7641 - val_loss: 1.4384 - val_accuracy: 0.5123
# Epoch 178/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5693 - accuracy: 0.7705 - val_loss: 1.4244 - val_accuracy: 0.5158
# Epoch 179/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5698 - accuracy: 0.7680 - val_loss: 1.4200 - val_accuracy: 0.5151
# Epoch 180/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5406 - accuracy: 0.7820 - val_loss: 1.4389 - val_accuracy: 0.5081
# Epoch 181/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5574 - accuracy: 0.7688 - val_loss: 1.4694 - val_accuracy: 0.5109
# Epoch 182/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5552 - accuracy: 0.7720 - val_loss: 1.4214 - val_accuracy: 0.5186
# Epoch 183/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5472 - accuracy: 0.7690 - val_loss: 1.4233 - val_accuracy: 0.5179
# Epoch 184/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5454 - accuracy: 0.7776 - val_loss: 1.4069 - val_accuracy: 0.5151
# Epoch 185/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5423 - accuracy: 0.7712 - val_loss: 1.3802 - val_accuracy: 0.5144
# Epoch 186/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5724 - accuracy: 0.7626 - val_loss: 1.4645 - val_accuracy: 0.4961
# Epoch 187/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5463 - accuracy: 0.7784 - val_loss: 1.4235 - val_accuracy: 0.5102
# Epoch 188/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5501 - accuracy: 0.7722 - val_loss: 1.3651 - val_accuracy: 0.5242
# Epoch 189/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5495 - accuracy: 0.7749 - val_loss: 1.4618 - val_accuracy: 0.4975
# Epoch 190/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5484 - accuracy: 0.7766 - val_loss: 1.4214 - val_accuracy: 0.5137
# Epoch 191/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5444 - accuracy: 0.7734 - val_loss: 1.4529 - val_accuracy: 0.5074
# Epoch 192/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5454 - accuracy: 0.7754 - val_loss: 1.5019 - val_accuracy: 0.5144
# Epoch 193/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5527 - accuracy: 0.7685 - val_loss: 1.4685 - val_accuracy: 0.5109
# Epoch 194/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5600 - accuracy: 0.7658 - val_loss: 1.4603 - val_accuracy: 0.5123
# Epoch 195/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5402 - accuracy: 0.7766 - val_loss: 1.4514 - val_accuracy: 0.5144
# Epoch 196/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5683 - accuracy: 0.7690 - val_loss: 1.4412 - val_accuracy: 0.5046
# Epoch 197/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5470 - accuracy: 0.7791 - val_loss: 1.4503 - val_accuracy: 0.5130
# Epoch 198/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5648 - accuracy: 0.7636 - val_loss: 1.4022 - val_accuracy: 0.5200
# Epoch 199/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5446 - accuracy: 0.7774 - val_loss: 1.4725 - val_accuracy: 0.5123
# Epoch 200/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5630 - accuracy: 0.7670 - val_loss: 1.4216 - val_accuracy: 0.5158
# Epoch 201/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5460 - accuracy: 0.7724 - val_loss: 1.4533 - val_accuracy: 0.5074
# Epoch 202/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5638 - accuracy: 0.7707 - val_loss: 1.4248 - val_accuracy: 0.5193
# Epoch 203/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5400 - accuracy: 0.7771 - val_loss: 1.4328 - val_accuracy: 0.5165
# Epoch 204/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5498 - accuracy: 0.7739 - val_loss: 1.4772 - val_accuracy: 0.5200
# Epoch 205/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5475 - accuracy: 0.7798 - val_loss: 1.4635 - val_accuracy: 0.5060
# Epoch 206/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5385 - accuracy: 0.7823 - val_loss: 1.4558 - val_accuracy: 0.5074
# Epoch 207/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5360 - accuracy: 0.7813 - val_loss: 1.4937 - val_accuracy: 0.5060
# Epoch 208/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5377 - accuracy: 0.7833 - val_loss: 1.4979 - val_accuracy: 0.5214
# Epoch 209/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5457 - accuracy: 0.7720 - val_loss: 1.4941 - val_accuracy: 0.5025
# Epoch 210/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5502 - accuracy: 0.7697 - val_loss: 1.4550 - val_accuracy: 0.5165
# Epoch 211/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5423 - accuracy: 0.7803 - val_loss: 1.4824 - val_accuracy: 0.5116
# Epoch 212/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5593 - accuracy: 0.7715 - val_loss: 1.4536 - val_accuracy: 0.5228
# Epoch 213/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5441 - accuracy: 0.7781 - val_loss: 1.4866 - val_accuracy: 0.5186
# Epoch 214/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5465 - accuracy: 0.7744 - val_loss: 1.4846 - val_accuracy: 0.5158
# Epoch 215/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5445 - accuracy: 0.7742 - val_loss: 1.5394 - val_accuracy: 0.4961
# Epoch 216/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5508 - accuracy: 0.7685 - val_loss: 1.4430 - val_accuracy: 0.5088
# Epoch 217/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5563 - accuracy: 0.7705 - val_loss: 1.4913 - val_accuracy: 0.4940
# Epoch 218/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5553 - accuracy: 0.7636 - val_loss: 1.4577 - val_accuracy: 0.5053
# Epoch 219/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5434 - accuracy: 0.7774 - val_loss: 1.4351 - val_accuracy: 0.5256
# Epoch 220/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5563 - accuracy: 0.7754 - val_loss: 1.4650 - val_accuracy: 0.5137
# Epoch 221/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5605 - accuracy: 0.7658 - val_loss: 1.4746 - val_accuracy: 0.5039
# Epoch 222/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5508 - accuracy: 0.7766 - val_loss: 1.5284 - val_accuracy: 0.4912
# Epoch 223/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5606 - accuracy: 0.7648 - val_loss: 1.5017 - val_accuracy: 0.5074
# Epoch 224/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5306 - accuracy: 0.7870 - val_loss: 1.4746 - val_accuracy: 0.5039
# Epoch 225/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5403 - accuracy: 0.7791 - val_loss: 1.4586 - val_accuracy: 0.5102
# Epoch 226/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5424 - accuracy: 0.7747 - val_loss: 1.4834 - val_accuracy: 0.5130
# Epoch 227/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5494 - accuracy: 0.7766 - val_loss: 1.4949 - val_accuracy: 0.5039
# Epoch 228/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5383 - accuracy: 0.7801 - val_loss: 1.5095 - val_accuracy: 0.5221
# Epoch 229/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5399 - accuracy: 0.7781 - val_loss: 1.5029 - val_accuracy: 0.5228
# Epoch 230/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5579 - accuracy: 0.7648 - val_loss: 1.5268 - val_accuracy: 0.5067
# Epoch 231/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5342 - accuracy: 0.7838 - val_loss: 1.5455 - val_accuracy: 0.5018
# Epoch 232/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5571 - accuracy: 0.7661 - val_loss: 1.5244 - val_accuracy: 0.4996
# Epoch 233/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5423 - accuracy: 0.7808 - val_loss: 1.5162 - val_accuracy: 0.5123
# Epoch 234/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5437 - accuracy: 0.7742 - val_loss: 1.5294 - val_accuracy: 0.5039
# Epoch 235/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5455 - accuracy: 0.7742 - val_loss: 1.5397 - val_accuracy: 0.5074
# Epoch 236/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5474 - accuracy: 0.7747 - val_loss: 1.5343 - val_accuracy: 0.5102
# Epoch 237/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5376 - accuracy: 0.7850 - val_loss: 1.5174 - val_accuracy: 0.5039
# Epoch 238/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5391 - accuracy: 0.7818 - val_loss: 1.5025 - val_accuracy: 0.5207
# Epoch 239/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5503 - accuracy: 0.7815 - val_loss: 1.5179 - val_accuracy: 0.5144
# Epoch 240/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5527 - accuracy: 0.7722 - val_loss: 1.5164 - val_accuracy: 0.5053
# Epoch 241/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5391 - accuracy: 0.7784 - val_loss: 1.5524 - val_accuracy: 0.4968
# Epoch 242/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5521 - accuracy: 0.7707 - val_loss: 1.5331 - val_accuracy: 0.5060
# Epoch 243/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5358 - accuracy: 0.7791 - val_loss: 1.5231 - val_accuracy: 0.5011
# Epoch 244/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5525 - accuracy: 0.7737 - val_loss: 1.5490 - val_accuracy: 0.5095
# Epoch 245/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5453 - accuracy: 0.7818 - val_loss: 1.5226 - val_accuracy: 0.5179
# Epoch 246/500
# 339/339 [==============================] - 1s 4ms/step - loss: 0.5402 - accuracy: 0.7791 - val_loss: 1.5304 - val_accuracy: 0.5165
# Epoch 247/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5562 - accuracy: 0.7739 - val_loss: 1.5138 - val_accuracy: 0.5151
# Epoch 248/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5397 - accuracy: 0.7840 - val_loss: 1.5061 - val_accuracy: 0.5081
# Epoch 249/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5339 - accuracy: 0.7833 - val_loss: 1.5418 - val_accuracy: 0.5116
# Epoch 250/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5427 - accuracy: 0.7761 - val_loss: 1.5520 - val_accuracy: 0.4975
# Epoch 251/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5376 - accuracy: 0.7818 - val_loss: 1.5345 - val_accuracy: 0.5081
# Epoch 252/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5500 - accuracy: 0.7791 - val_loss: 1.5428 - val_accuracy: 0.4989
# Epoch 253/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5350 - accuracy: 0.7828 - val_loss: 1.5215 - val_accuracy: 0.5137
# Epoch 254/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5253 - accuracy: 0.7850 - val_loss: 1.5677 - val_accuracy: 0.5011
# Epoch 255/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5440 - accuracy: 0.7796 - val_loss: 1.5107 - val_accuracy: 0.5123
# Epoch 256/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5325 - accuracy: 0.7823 - val_loss: 1.5718 - val_accuracy: 0.5067
# Epoch 257/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5369 - accuracy: 0.7798 - val_loss: 1.5310 - val_accuracy: 0.5109
# Epoch 258/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5324 - accuracy: 0.7833 - val_loss: 1.5508 - val_accuracy: 0.5109
# Epoch 259/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5316 - accuracy: 0.7825 - val_loss: 1.5318 - val_accuracy: 0.5151
# Epoch 260/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5380 - accuracy: 0.7815 - val_loss: 1.5440 - val_accuracy: 0.5109
# Epoch 261/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5374 - accuracy: 0.7811 - val_loss: 1.5184 - val_accuracy: 0.5256
# Epoch 262/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5256 - accuracy: 0.7860 - val_loss: 1.5177 - val_accuracy: 0.5088
# Epoch 263/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5390 - accuracy: 0.7793 - val_loss: 1.5024 - val_accuracy: 0.5291
# Epoch 264/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5422 - accuracy: 0.7798 - val_loss: 1.5134 - val_accuracy: 0.5137
# Epoch 265/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5369 - accuracy: 0.7803 - val_loss: 1.5160 - val_accuracy: 0.5179
# Epoch 266/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5304 - accuracy: 0.7855 - val_loss: 1.5180 - val_accuracy: 0.5158
# Epoch 267/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5320 - accuracy: 0.7828 - val_loss: 1.5664 - val_accuracy: 0.5060
# Epoch 268/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5186 - accuracy: 0.7909 - val_loss: 1.5185 - val_accuracy: 0.5130
# Epoch 269/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5263 - accuracy: 0.7872 - val_loss: 1.5401 - val_accuracy: 0.5088
# Epoch 270/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5559 - accuracy: 0.7715 - val_loss: 1.4785 - val_accuracy: 0.5004
# Epoch 271/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5323 - accuracy: 0.7833 - val_loss: 1.5229 - val_accuracy: 0.5067
# Epoch 272/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5333 - accuracy: 0.7855 - val_loss: 1.5368 - val_accuracy: 0.5053
# Epoch 273/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5474 - accuracy: 0.7695 - val_loss: 1.5429 - val_accuracy: 0.5046
# Epoch 274/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5319 - accuracy: 0.7779 - val_loss: 1.5394 - val_accuracy: 0.5179
# Epoch 275/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5421 - accuracy: 0.7786 - val_loss: 1.5437 - val_accuracy: 0.5123
# Epoch 276/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5286 - accuracy: 0.7929 - val_loss: 1.5192 - val_accuracy: 0.5046
# Epoch 277/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5403 - accuracy: 0.7784 - val_loss: 1.5573 - val_accuracy: 0.5116
# Epoch 278/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5321 - accuracy: 0.7887 - val_loss: 1.5415 - val_accuracy: 0.5039
# Epoch 279/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5390 - accuracy: 0.7774 - val_loss: 1.5124 - val_accuracy: 0.5214
# Epoch 280/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5419 - accuracy: 0.7754 - val_loss: 1.5590 - val_accuracy: 0.4989
# Epoch 281/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5491 - accuracy: 0.7727 - val_loss: 1.5734 - val_accuracy: 0.4856
# Epoch 282/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5393 - accuracy: 0.7774 - val_loss: 1.5048 - val_accuracy: 0.5011
# Epoch 283/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5287 - accuracy: 0.7756 - val_loss: 1.5738 - val_accuracy: 0.5151
# Epoch 284/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5393 - accuracy: 0.7798 - val_loss: 1.4889 - val_accuracy: 0.5179
# Epoch 285/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5198 - accuracy: 0.7894 - val_loss: 1.5504 - val_accuracy: 0.5109
# Epoch 286/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5363 - accuracy: 0.7769 - val_loss: 1.5710 - val_accuracy: 0.5151
# Epoch 287/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5218 - accuracy: 0.7889 - val_loss: 1.5169 - val_accuracy: 0.5235
# Epoch 288/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5312 - accuracy: 0.7835 - val_loss: 1.5715 - val_accuracy: 0.5060
# Epoch 289/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5335 - accuracy: 0.7813 - val_loss: 1.5216 - val_accuracy: 0.5207
# Epoch 290/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5478 - accuracy: 0.7700 - val_loss: 1.5606 - val_accuracy: 0.5088
# Epoch 291/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5325 - accuracy: 0.7875 - val_loss: 1.5657 - val_accuracy: 0.5046
# Epoch 292/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5291 - accuracy: 0.7884 - val_loss: 1.5354 - val_accuracy: 0.5235
# Epoch 293/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5431 - accuracy: 0.7705 - val_loss: 1.5426 - val_accuracy: 0.5046
# Epoch 294/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5185 - accuracy: 0.7926 - val_loss: 1.5852 - val_accuracy: 0.5032
# Epoch 295/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5274 - accuracy: 0.7843 - val_loss: 1.5998 - val_accuracy: 0.4919
# Epoch 296/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5206 - accuracy: 0.7914 - val_loss: 1.5318 - val_accuracy: 0.5109
# Epoch 297/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5500 - accuracy: 0.7766 - val_loss: 1.5267 - val_accuracy: 0.5130
# Epoch 298/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5329 - accuracy: 0.7823 - val_loss: 1.5342 - val_accuracy: 0.5095
# Epoch 299/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5270 - accuracy: 0.7894 - val_loss: 1.5206 - val_accuracy: 0.5081
# Epoch 300/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5272 - accuracy: 0.7828 - val_loss: 1.5522 - val_accuracy: 0.5144
# Epoch 301/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5271 - accuracy: 0.7860 - val_loss: 1.5009 - val_accuracy: 0.5256
# Epoch 302/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5368 - accuracy: 0.7936 - val_loss: 1.5220 - val_accuracy: 0.4996
# Epoch 303/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5040 - accuracy: 0.7948 - val_loss: 1.5968 - val_accuracy: 0.5025
# Epoch 304/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5249 - accuracy: 0.7879 - val_loss: 1.5490 - val_accuracy: 0.5095
# Epoch 305/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5362 - accuracy: 0.7882 - val_loss: 1.5041 - val_accuracy: 0.5165
# Epoch 306/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5376 - accuracy: 0.7806 - val_loss: 1.5750 - val_accuracy: 0.5025
# Epoch 307/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5382 - accuracy: 0.7815 - val_loss: 1.5630 - val_accuracy: 0.5081
# Epoch 308/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5282 - accuracy: 0.7830 - val_loss: 1.5447 - val_accuracy: 0.5046
# Epoch 309/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5189 - accuracy: 0.7847 - val_loss: 1.5804 - val_accuracy: 0.5088
# Epoch 310/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5249 - accuracy: 0.7877 - val_loss: 1.5174 - val_accuracy: 0.5242
# Epoch 311/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5235 - accuracy: 0.7931 - val_loss: 1.5380 - val_accuracy: 0.5186
# Epoch 312/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5384 - accuracy: 0.7887 - val_loss: 1.5494 - val_accuracy: 0.5081
# Epoch 313/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5267 - accuracy: 0.7872 - val_loss: 1.5659 - val_accuracy: 0.5067
# Epoch 314/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5310 - accuracy: 0.7879 - val_loss: 1.5665 - val_accuracy: 0.5025
# Epoch 315/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5330 - accuracy: 0.7825 - val_loss: 1.5779 - val_accuracy: 0.5088
# Epoch 316/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5131 - accuracy: 0.7975 - val_loss: 1.5585 - val_accuracy: 0.5060
# Epoch 317/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5242 - accuracy: 0.7870 - val_loss: 1.5992 - val_accuracy: 0.5018
# Epoch 318/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5207 - accuracy: 0.7865 - val_loss: 1.6193 - val_accuracy: 0.5025
# Epoch 319/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5093 - accuracy: 0.7931 - val_loss: 1.5513 - val_accuracy: 0.5130
# Epoch 320/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5211 - accuracy: 0.7865 - val_loss: 1.5786 - val_accuracy: 0.5116
# Epoch 321/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5302 - accuracy: 0.7904 - val_loss: 1.5531 - val_accuracy: 0.5151
# Epoch 322/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5245 - accuracy: 0.7914 - val_loss: 1.5401 - val_accuracy: 0.5137
# Epoch 323/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5314 - accuracy: 0.7838 - val_loss: 1.5573 - val_accuracy: 0.5046
# Epoch 324/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5188 - accuracy: 0.7892 - val_loss: 1.5302 - val_accuracy: 0.5179
# Epoch 325/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5196 - accuracy: 0.7929 - val_loss: 1.5419 - val_accuracy: 0.5095
# Epoch 326/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5222 - accuracy: 0.7879 - val_loss: 1.5686 - val_accuracy: 0.5025
# Epoch 327/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5195 - accuracy: 0.7835 - val_loss: 1.5522 - val_accuracy: 0.5207
# Epoch 328/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5180 - accuracy: 0.7958 - val_loss: 1.5145 - val_accuracy: 0.5242
# Epoch 329/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5292 - accuracy: 0.7803 - val_loss: 1.5999 - val_accuracy: 0.4954
# Epoch 330/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5271 - accuracy: 0.7857 - val_loss: 1.5301 - val_accuracy: 0.5186
# Epoch 331/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5218 - accuracy: 0.7934 - val_loss: 1.5539 - val_accuracy: 0.5193
# Epoch 332/500
# ...
# Epoch 391/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5223 - accuracy: 0.7850 - val_loss: 1.6271 - val_accuracy: 0.5123
# Epoch 392/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5106 - accuracy: 0.7911 - val_loss: 1.6778 - val_accuracy: 0.5039
# Epoch 393/500
# 339/339 [==============================] - 2s 4ms/step - loss: 0.5079 - accuracy: 0.7884 - val_loss: 1.6496 - val_accuracy: 0.5123
# Epoch 394/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5285 - accuracy: 0.7852 - val_loss: 1.6284 - val_accuracy: 0.5130
# Epoch 395/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5156 - accuracy: 0.7897 - val_loss: 1.6132 - val_accuracy: 0.5158
# Epoch 396/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5234 - accuracy: 0.7860 - val_loss: 1.6289 - val_accuracy: 0.5137
# Epoch 397/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5301 - accuracy: 0.7845 - val_loss: 1.5847 - val_accuracy: 0.5186
# Epoch 398/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5077 - accuracy: 0.8002 - val_loss: 1.6157 - val_accuracy: 0.5165
# Epoch 399/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5072 - accuracy: 0.7902 - val_loss: 1.6385 - val_accuracy: 0.5144
# Epoch 400/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5105 - accuracy: 0.7909 - val_loss: 1.6815 - val_accuracy: 0.5046
# Epoch 401/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5364 - accuracy: 0.7830 - val_loss: 1.6200 - val_accuracy: 0.5172
# Epoch 402/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5113 - accuracy: 0.7924 - val_loss: 1.6498 - val_accuracy: 0.5095
# Epoch 403/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5278 - accuracy: 0.7894 - val_loss: 1.6413 - val_accuracy: 0.4989
# Epoch 404/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5105 - accuracy: 0.7902 - val_loss: 1.6505 - val_accuracy: 0.5109
# Epoch 405/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5154 - accuracy: 0.7909 - val_loss: 1.6222 - val_accuracy: 0.5144
# Epoch 406/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5206 - accuracy: 0.7894 - val_loss: 1.6232 - val_accuracy: 0.5067
# Epoch 407/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5201 - accuracy: 0.7899 - val_loss: 1.6510 - val_accuracy: 0.5137
# Epoch 408/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5183 - accuracy: 0.7830 - val_loss: 1.6406 - val_accuracy: 0.5165
# Epoch 409/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5163 - accuracy: 0.7899 - val_loss: 1.6330 - val_accuracy: 0.5130
# Epoch 410/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5250 - accuracy: 0.7897 - val_loss: 1.6149 - val_accuracy: 0.5095
# Epoch 411/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5177 - accuracy: 0.7877 - val_loss: 1.6331 - val_accuracy: 0.5130
# Epoch 412/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5064 - accuracy: 0.7921 - val_loss: 1.6339 - val_accuracy: 0.5158
# Epoch 413/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4959 - accuracy: 0.8042 - val_loss: 1.6312 - val_accuracy: 0.5116
# Epoch 414/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5050 - accuracy: 0.7951 - val_loss: 1.6859 - val_accuracy: 0.4989
# Epoch 415/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5083 - accuracy: 0.7889 - val_loss: 1.6371 - val_accuracy: 0.5200
# Epoch 416/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5222 - accuracy: 0.7887 - val_loss: 1.6423 - val_accuracy: 0.5109
# Epoch 417/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5166 - accuracy: 0.7887 - val_loss: 1.6302 - val_accuracy: 0.5144
# Epoch 418/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5078 - accuracy: 0.7975 - val_loss: 1.6130 - val_accuracy: 0.5158
# Epoch 419/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5166 - accuracy: 0.7884 - val_loss: 1.5924 - val_accuracy: 0.5144
# Epoch 420/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5182 - accuracy: 0.7961 - val_loss: 1.5987 - val_accuracy: 0.5214
# Epoch 421/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5081 - accuracy: 0.7929 - val_loss: 1.6742 - val_accuracy: 0.5158
# Epoch 422/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5113 - accuracy: 0.7931 - val_loss: 1.6418 - val_accuracy: 0.5172
# Epoch 423/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5301 - accuracy: 0.7852 - val_loss: 1.6463 - val_accuracy: 0.5067
# Epoch 424/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5030 - accuracy: 0.7916 - val_loss: 1.6314 - val_accuracy: 0.5200
# Epoch 425/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5032 - accuracy: 0.8000 - val_loss: 1.6363 - val_accuracy: 0.5137
# Epoch 426/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5032 - accuracy: 0.7936 - val_loss: 1.6130 - val_accuracy: 0.5172
# Epoch 427/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5172 - accuracy: 0.7897 - val_loss: 1.6149 - val_accuracy: 0.5221
# Epoch 428/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5218 - accuracy: 0.7916 - val_loss: 1.6477 - val_accuracy: 0.5151
# Epoch 429/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5095 - accuracy: 0.7968 - val_loss: 1.6587 - val_accuracy: 0.5123
# Epoch 430/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5083 - accuracy: 0.7897 - val_loss: 1.6199 - val_accuracy: 0.5193
# Epoch 431/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5062 - accuracy: 0.7916 - val_loss: 1.7049 - val_accuracy: 0.4926
# Epoch 432/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5139 - accuracy: 0.7857 - val_loss: 1.6557 - val_accuracy: 0.5074
# Epoch 433/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5072 - accuracy: 0.7948 - val_loss: 1.6669 - val_accuracy: 0.5144
# Epoch 434/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5078 - accuracy: 0.7978 - val_loss: 1.6507 - val_accuracy: 0.5081
# Epoch 435/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5140 - accuracy: 0.7934 - val_loss: 1.5969 - val_accuracy: 0.5256
# Epoch 436/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5149 - accuracy: 0.7963 - val_loss: 1.6230 - val_accuracy: 0.5165
# Epoch 437/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5017 - accuracy: 0.8012 - val_loss: 1.6660 - val_accuracy: 0.5158
# Epoch 438/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5121 - accuracy: 0.7902 - val_loss: 1.6539 - val_accuracy: 0.5081
# Epoch 439/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5079 - accuracy: 0.7916 - val_loss: 1.6172 - val_accuracy: 0.5144
# Epoch 440/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5071 - accuracy: 0.7948 - val_loss: 1.6383 - val_accuracy: 0.5151
# Epoch 441/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5226 - accuracy: 0.7845 - val_loss: 1.6166 - val_accuracy: 0.5123
# Epoch 442/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5173 - accuracy: 0.7963 - val_loss: 1.6341 - val_accuracy: 0.5095
# Epoch 443/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5095 - accuracy: 0.7926 - val_loss: 1.6496 - val_accuracy: 0.5095
# Epoch 444/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5060 - accuracy: 0.7943 - val_loss: 1.6070 - val_accuracy: 0.5158
# Epoch 445/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5095 - accuracy: 0.7946 - val_loss: 1.6388 - val_accuracy: 0.5172
# Epoch 446/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5250 - accuracy: 0.7924 - val_loss: 1.5852 - val_accuracy: 0.5179
# Epoch 447/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5056 - accuracy: 0.7951 - val_loss: 1.6193 - val_accuracy: 0.5151
# Epoch 448/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5113 - accuracy: 0.7926 - val_loss: 1.6034 - val_accuracy: 0.5102
# Epoch 449/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5146 - accuracy: 0.7985 - val_loss: 1.5846 - val_accuracy: 0.5137
# Epoch 450/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5061 - accuracy: 0.7975 - val_loss: 1.5552 - val_accuracy: 0.5172
# Epoch 451/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5115 - accuracy: 0.8030 - val_loss: 1.5891 - val_accuracy: 0.5200
# Epoch 452/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5113 - accuracy: 0.7902 - val_loss: 1.5854 - val_accuracy: 0.5088
# Epoch 453/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4956 - accuracy: 0.8071 - val_loss: 1.6172 - val_accuracy: 0.5151
# Epoch 454/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5131 - accuracy: 0.7946 - val_loss: 1.6495 - val_accuracy: 0.5060
# Epoch 455/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5242 - accuracy: 0.7951 - val_loss: 1.6145 - val_accuracy: 0.5179
# Epoch 456/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5099 - accuracy: 0.7943 - val_loss: 1.5801 - val_accuracy: 0.5144
# Epoch 457/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5268 - accuracy: 0.7884 - val_loss: 1.5830 - val_accuracy: 0.5109
# Epoch 458/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5072 - accuracy: 0.7980 - val_loss: 1.6266 - val_accuracy: 0.5116
# Epoch 459/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5083 - accuracy: 0.7892 - val_loss: 1.5932 - val_accuracy: 0.5235
# Epoch 460/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5136 - accuracy: 0.7875 - val_loss: 1.5994 - val_accuracy: 0.5193
# Epoch 461/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5155 - accuracy: 0.7887 - val_loss: 1.5894 - val_accuracy: 0.5186
# Epoch 462/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5059 - accuracy: 0.7929 - val_loss: 1.6225 - val_accuracy: 0.5151
# Epoch 463/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5131 - accuracy: 0.7951 - val_loss: 1.5992 - val_accuracy: 0.5291
# Epoch 464/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5109 - accuracy: 0.7916 - val_loss: 1.6413 - val_accuracy: 0.5137
# Epoch 465/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5113 - accuracy: 0.7934 - val_loss: 1.5995 - val_accuracy: 0.5109
# Epoch 466/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5078 - accuracy: 0.7963 - val_loss: 1.6146 - val_accuracy: 0.5165
# Epoch 467/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5252 - accuracy: 0.7894 - val_loss: 1.6188 - val_accuracy: 0.5102
# Epoch 468/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5016 - accuracy: 0.7936 - val_loss: 1.6457 - val_accuracy: 0.5137
# Epoch 469/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4947 - accuracy: 0.7985 - val_loss: 1.6269 - val_accuracy: 0.5095
# Epoch 470/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5129 - accuracy: 0.7852 - val_loss: 1.6434 - val_accuracy: 0.5116
# Epoch 471/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5170 - accuracy: 0.7904 - val_loss: 1.6137 - val_accuracy: 0.5200
# Epoch 472/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4868 - accuracy: 0.8064 - val_loss: 1.6656 - val_accuracy: 0.5074
# Epoch 473/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5129 - accuracy: 0.7892 - val_loss: 1.6149 - val_accuracy: 0.5165
# Epoch 474/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5193 - accuracy: 0.7806 - val_loss: 1.6732 - val_accuracy: 0.4989
# Epoch 475/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5076 - accuracy: 0.7943 - val_loss: 1.6478 - val_accuracy: 0.5074
# Epoch 476/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5103 - accuracy: 0.7904 - val_loss: 1.6025 - val_accuracy: 0.5151
# Epoch 477/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5071 - accuracy: 0.7963 - val_loss: 1.6352 - val_accuracy: 0.5137
# Epoch 478/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5119 - accuracy: 0.7953 - val_loss: 1.6352 - val_accuracy: 0.5060
# Epoch 479/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4980 - accuracy: 0.7975 - val_loss: 1.6235 - val_accuracy: 0.5102
# Epoch 480/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5053 - accuracy: 0.7921 - val_loss: 1.6102 - val_accuracy: 0.5165
# Epoch 481/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5109 - accuracy: 0.7916 - val_loss: 1.6575 - val_accuracy: 0.5053
# Epoch 482/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5064 - accuracy: 0.7966 - val_loss: 1.6474 - val_accuracy: 0.5116
# Epoch 483/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5067 - accuracy: 0.7995 - val_loss: 1.6398 - val_accuracy: 0.5137
# Epoch 484/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5025 - accuracy: 0.8005 - val_loss: 1.6098 - val_accuracy: 0.5200
# Epoch 485/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4979 - accuracy: 0.7993 - val_loss: 1.6114 - val_accuracy: 0.5291
# Epoch 486/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5215 - accuracy: 0.7894 - val_loss: 1.6222 - val_accuracy: 0.5200
# Epoch 487/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5067 - accuracy: 0.7911 - val_loss: 1.6203 - val_accuracy: 0.5193
# Epoch 488/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4985 - accuracy: 0.8000 - val_loss: 1.6435 - val_accuracy: 0.5137
# Epoch 489/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5068 - accuracy: 0.7946 - val_loss: 1.6385 - val_accuracy: 0.5179
# Epoch 490/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4965 - accuracy: 0.7985 - val_loss: 1.6802 - val_accuracy: 0.5039
# Epoch 491/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5066 - accuracy: 0.7956 - val_loss: 1.6856 - val_accuracy: 0.5081
# Epoch 492/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5176 - accuracy: 0.7899 - val_loss: 1.6630 - val_accuracy: 0.5137
# Epoch 493/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5174 - accuracy: 0.7899 - val_loss: 1.6510 - val_accuracy: 0.5102
# Epoch 494/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4962 - accuracy: 0.7983 - val_loss: 1.6486 - val_accuracy: 0.5179
# Epoch 495/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4986 - accuracy: 0.7990 - val_loss: 1.6389 - val_accuracy: 0.5151
# Epoch 496/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5034 - accuracy: 0.7938 - val_loss: 1.6729 - val_accuracy: 0.5011
# Epoch 497/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5148 - accuracy: 0.7978 - val_loss: 1.6733 - val_accuracy: 0.5109
# Epoch 498/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5086 - accuracy: 0.7948 - val_loss: 1.6582 - val_accuracy: 0.5116
# Epoch 499/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.5064 - accuracy: 0.7882 - val_loss: 1.6355 - val_accuracy: 0.5172
# Epoch 500/500
# 339/339 [==============================] - 2s 5ms/step - loss: 0.4942 - accuracy: 0.8081 - val_loss: 1.6684 - val_accuracy: 0.5151

# %%
plt.plot(hist.history['loss'], label='train loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# %%
plt.plot(hist.history['accuracy'], label='train acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
y_pred = model.predict(X_test)

# %%
# Calculate the accuracy
test_preds = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
test_acc = np.sum(test_preds == y_true)/y_true.shape[0]

# Recall for each class
recall_vals = []
for i in range(3):
    class_idx = np.argwhere(y_true==i)
    total = len(class_idx)
    correct = np.sum(test_preds[class_idx]==i)
    recall = correct / total
    recall_vals.append(recall)

classes = [0,1,2]
# Calculate the test set accuracy and recall for each class
print('Test set accuracy is {:.3f}'.format(test_acc))
for i in range(3):
    print('For class {}, recall is {:.3f}'.format(classes[i],recall_vals[i]))

print("Accuracy is {:.3f}".format(test_acc))
# print("Weighted F score is {:.3f}".format(calculate_weighted_f_score(y_true, y_pred)))
# Out:
# Test set accuracy is 0.606
# For class 0, recall is 0.825
# For class 1, recall is 0.147
# For class 2, recall is 0.845
# Accuracy is 0.606

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / np.sum(cm).astype('float')
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

nb_classes = 2

# Confusion matrix
conf_mat=confusion_matrix(y_true, np.argmax(y_pred, axis=-1))
plot_confusion_matrix(conf_mat, [0,1,2])

from sklearn.metrics import precision_score

precision_score(y_true, np.argmax(y_pred, axis=-1), average='weighted')

from sklearn.metrics import classification_report

print(classification_report(y_true, np.argmax(y_pred, axis=-1), target_names=["flat","down", "up"], digits=4))
# Out:
#               precision    recall  f1-score   support
#
#         flat     0.4763    0.8254    0.6041       378
#         down     0.9808    0.1474    0.2563       346
#           up     0.8018    0.8449    0.8228       316
#
#     accuracy                         0.6058      1040
#    macro avg     0.7530    0.6059    0.5611      1040
# weighted avg     0.7430    0.6058    0.5548      1040

# %%
def calculate_weighted_f_score(y_true, y_pred):
  test_preds = np.argmax(y_pred, axis=-1)
  Ntu = sum((test_preds == 1) & (y_true == 1))
  Ntd = sum((test_preds == 0) & (y_true == 0))
  Ntf = sum((test_preds == 2) & (y_true == 2))
  Ewutd = sum((test_preds == 1) & (y_true == 0))
  Ewdtu = sum((test_preds == 0) & (y_true == 1))
  Ewutf = sum((test_preds == 1) & (y_true == 2))
  Ewdtf = sum((test_preds == 0) & (y_true == 2))
  Ewftu = sum((test_preds == 2) & (y_true == 1))
  Ewftd = sum((test_preds == 2) & (y_true == 0))

  beta_1 = 0.5
  beta_2 = 0.125
  beta_3 = 0.125

  Ntp = Ntu + Ntd + beta_3**2 * Ntf
  E1 = Ewutd + Ewdtu
  E2 = Ewutf + Ewdtf
  E3 = Ewftu + Ewftd

  F = (1 + beta_1**2 + beta_2**2) * Ntp / ((1+beta_1**2+beta_2**2) * Ntp + E1 + beta_1**2 * E2 + beta_2**2 * E3)
  return  F

print(f'Weight CDT F Score: {calculate_weighted_f_score(y_true, y_pred)}')
# Out:
# Weight CDT F Score: 0.6011798597597895

# %%
def calculate_weighted_f_score(y_true, y_pred):
  test_preds = np.argmax(y_pred, axis=1)
  Ntu = sum((test_preds == 1) & (y_true == 1))
  Ntd = sum((test_preds == 0) & (y_true == 0))
  Ntf = sum((test_preds == 2) & (y_true == 2))
  Ewutd = sum((test_preds == 1) & (y_true == 0))
  Ewdtu = sum((test_preds == 0) & (y_true == 1))
  Ewutf = sum((test_preds == 1) & (y_true == 2))
  Ewdtf = sum((test_preds == 0) & (y_true == 2))
  Ewftu = sum((test_preds == 2) & (y_true == 1))
  Ewftd = sum((test_preds == 2) & (y_true == 0))

  beta_1 = 0.5
  beta_2 = 0.125
  beta_3 = 0.125

  Ntp = Ntu + Ntd + beta_3**2 * Ntf
  E1 = Ewutd + Ewdtu
  E2 = Ewutf + Ewdtf
  E3 = Ewftu + Ewftd

  F = (1 + beta_1**2 + beta_2**2) * Ntp / ((1+beta_1**2+beta_2**2) * Ntp + E1 + beta_1**2 * E2 + beta_2**2 * E3)
  return F

# %%
print(X_train.shape[1],X_train.shape[2])
# Out:
# 5 24

# %%
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=(X_train.shape[1],X_train.shape[2])))
model.add(MaxPooling1D(pool_size=3, strides=4, padding='same'))
model.add(Dropout(0.7))
model.add(Conv1D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=3, strides=3, padding='same'))
model.add(Dropout(0.7))
model.add(Conv1D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
model.add(Dropout(0.7))
model.add(Flatten())
model.add(Dense(1000,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(2,activation="softmax"))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_18 (Conv1D)          (None, 5, 32)             2336
#
#  max_pooling1d_18 (MaxPoolin  (None, 2, 32)            0
#  g1D)
#
#  dropout_18 (Dropout)        (None, 2, 32)             0
#
#  conv1d_19 (Conv1D)          (None, 2, 64)             6208
#
#  max_pooling1d_19 (MaxPoolin  (None, 1, 64)            0
#  g1D)
#
#  dropout_19 (Dropout)        (None, 1, 64)             0
#
#  conv1d_20 (Conv1D)          (None, 1, 128)            24704
#
#  max_pooling1d_20 (MaxPoolin  (None, 1, 128)           0
#  g1D)
#
#  dropout_20 (Dropout)        (None, 1, 128)            0
#
#  flatten_6 (Flatten)         (None, 128)               0
#
#  dense_16 (Dense)            (None, 1000)              129000
#
#  dense_17 (Dense)            (None, 500)               500500
#
#  dense_18 (Dense)            (None, 2)                 1002
#
# =================================================================
# Total params: 663,750
# Trainable params: 663,750
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(learning_rate=0.001, decay=0.0001)
nadam = Nadam(learning_rate=0.002, beta_1=0.9, beta_2=0.999, epsilon=1e-08, schedule_decay=0.004)

def custom_loss_function(y_true, y_pred):
   squared_difference = tf.square(y_true - y_pred)
   return tf.reduce_mean(squared_difference, axis=-1)

def calculate_weighted_f_score(y_true, y_pred):
  test_preds = np.argmax(y_pred, axis=-1)
  print(test_preds)
  Ntu = sum((test_preds == 1) & (y_true == 1))
  Ntd = sum((test_preds == 0) & (y_true == 0))
  Ntf = sum((test_preds == 2) & (y_true == 2))
  Ewutd = sum((test_preds == 1) & (y_true == 0))
  Ewdtu = sum((test_preds == 0) & (y_true == 1))
  Ewutf = sum((test_preds == 1) & (y_true == 2))
  Ewdtf = sum((test_preds == 0) & (y_true == 2))
  Ewftu = sum((test_preds == 2) & (y_true == 1))
  Ewftd = sum((test_preds == 2) & (y_true == 0))

  beta_1 = 0.5
  beta_2 = 0.125
  beta_3 = 0.125

  Ntp = Ntu + Ntd + beta_3**2 * Ntf
  E1 = Ewutd + Ewdtu
  E2 = Ewutf + Ewdtf
  E3 = Ewftu + Ewftd

  F = (1 + beta_1**2 + beta_2**2) * Ntp / ((1+beta_1**2+beta_2**2) * Ntp + E1 + beta_1**2 * E2 + beta_2**2 * E3)
  return  F

prec = tf.keras.metrics.Precision()

model.compile(loss='binary_crossentropy', optimizer=adam, metrics=[prec])

# %%
batch_size = 12
hist = model.fit(X_train, y_train, batch_size=batch_size, epochs=50, validation_data=(X_val, y_val)) #, class_weight={0:2, 1:3, 2:1})
# Out:
# Epoch 1/50
# 352/352 [==============================] - 3s 6ms/step - loss: 0.6739 - precision_7: 0.6014 - val_loss: 0.6729 - val_precision_7: 0.6007
# Epoch 2/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6746 - precision_7: 0.6019 - val_loss: 0.6747 - val_precision_7: 0.6007
# Epoch 3/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6734 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 4/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6727 - precision_7: 0.6019 - val_loss: 0.6751 - val_precision_7: 0.6007
# Epoch 5/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6733 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 6/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6730 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 7/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6728 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 8/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6726 - precision_7: 0.6019 - val_loss: 0.6737 - val_precision_7: 0.6007
# Epoch 9/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6728 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 10/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6729 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 11/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6732 - precision_7: 0.6019 - val_loss: 0.6734 - val_precision_7: 0.6007
# Epoch 12/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6726 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 13/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6729 - val_precision_7: 0.6007
# Epoch 14/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6726 - precision_7: 0.6019 - val_loss: 0.6730 - val_precision_7: 0.6007
# Epoch 15/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6730 - val_precision_7: 0.6007
# Epoch 16/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6726 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 17/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6728 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 18/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6726 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 19/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6017 - val_loss: 0.6731 - val_precision_7: 0.6007
# Epoch 20/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6726 - precision_7: 0.6019 - val_loss: 0.6730 - val_precision_7: 0.6007
# Epoch 21/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6727 - precision_7: 0.6019 - val_loss: 0.6730 - val_precision_7: 0.6007
# Epoch 22/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6727 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 23/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6726 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 24/50
# 352/352 [==============================] - 2s 6ms/step - loss: 0.6726 - precision_7: 0.6019 - val_loss: 0.6729 - val_precision_7: 0.6007
# Epoch 25/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6730 - val_precision_7: 0.6007
# Epoch 26/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6726 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 27/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6726 - precision_7: 0.6019 - val_loss: 0.6729 - val_precision_7: 0.6007
# Epoch 28/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 29/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 30/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 31/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 32/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6723 - precision_7: 0.6019 - val_loss: 0.6729 - val_precision_7: 0.6007
# Epoch 33/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6724 - precision_7: 0.6026 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 34/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6017 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 35/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6724 - precision_7: 0.6019 - val_loss: 0.6729 - val_precision_7: 0.6007
# Epoch 36/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6724 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 37/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6727 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 38/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 39/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 40/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6724 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 41/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 42/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 43/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6724 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 44/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6724 - precision_7: 0.6019 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 45/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6727 - precision_7: 0.6014 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 46/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6722 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 47/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6724 - precision_7: 0.6017 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 48/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6725 - precision_7: 0.6019 - val_loss: 0.6728 - val_precision_7: 0.6007
# Epoch 49/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6724 - precision_7: 0.6017 - val_loss: 0.6727 - val_precision_7: 0.6007
# Epoch 50/50
# 352/352 [==============================] - 2s 5ms/step - loss: 0.6724 - precision_7: 0.6009 - val_loss: 0.6738 - val_precision_7: 0.6007

# %%
hist.history
# Out:
# {'loss': [0.6739199161529541,
#   0.6745873689651489,
#   0.673353374004364,
#   0.6727477312088013,
#   0.6732865571975708,
#   0.6729598045349121,
#   0.6728412508964539,
#   0.6726021766662598,
#   0.6728477478027344,
#   0.6728655695915222,
#   0.6732037663459778,
#   0.6726383566856384,
#   0.6725048422813416,
#   0.6726340055465698,
#   0.6724653244018555,
#   0.6726179718971252,
#   0.6727598905563354,
#   0.6725648641586304,
#   0.6725471615791321,
#   0.6725770235061646,
#   0.6726747155189514,
#   0.6726670861244202,
#   0.6725931167602539,
#   0.6725555658340454,
#   0.6725409030914307,
#   0.6725565195083618,
#   0.6725572943687439,
#   0.6725035905838013,
#   0.6724714040756226,
#   0.6725125908851624,
#   0.672520101070404,
#   0.6723334193229675,
#   0.6723588705062866,
#   0.6725103259086609,
#   0.6724315285682678,
#   0.6723941564559937,
#   0.672657310962677,
#   0.6724977493286133,
#   0.6724774241447449,
#   0.6724062561988831,
#   0.6724578142166138,
#   0.6725069880485535,
#   0.6724458336830139,
#   0.672408938407898,
#   0.672699511051178,
#   0.6722479462623596,
#   0.6723613739013672,
#   0.6724828481674194,
#   0.6723563075065613,
#   0.672439694404602],
#  'precision_7': [0.6014217734336853,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6016587615013123,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6026066541671753,
#   0.6016587615013123,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6018957495689392,
#   0.6014217734336853,
#   0.6018957495689392,
#   0.6016587615013123,
#   0.6018957495689392,
#   0.6016587615013123,
#   0.6009478569030762],
#  'val_loss': [0.6729004979133606,
#   0.6747092604637146,
#   0.6727417707443237,
#   0.6751312613487244,
#   0.6727463006973267,
#   0.672755241394043,
#   0.6727584600448608,
#   0.6737393736839294,
#   0.6728079319000244,
#   0.6728230714797974,
#   0.6733888387680054,
#   0.6727582812309265,
#   0.6729012131690979,
#   0.672968327999115,
#   0.6730093359947205,
#   0.6727268695831299,
#   0.6727235913276672,
#   0.672727644443512,
#   0.6730960011482239,
#   0.6729731559753418,
#   0.6729639172554016,
#   0.6727637052536011,
#   0.6727550029754639,
#   0.6728544235229492,
#   0.6729679107666016,
#   0.6727513670921326,
#   0.6728929877281189,
#   0.6727278828620911,
#   0.672716498374939,
#   0.672760546207428,
#   0.6728389263153076,
#   0.6729355454444885,
#   0.6727286577224731,
#   0.6727634072303772,
#   0.6728515028953552,
#   0.67275470495224,
#   0.6727381944656372,
#   0.6727297306060791,
#   0.6727380156517029,
#   0.672787606716156,
#   0.6727962493896484,
#   0.6727461218833923,
#   0.6727689504623413,
#   0.6727339029312134,
#   0.6727678775787354,
#   0.6728211045265198,
#   0.6727349162101746,
#   0.6727569699287415,
#   0.6727298498153687,
#   0.6737827062606812],
#  'val_precision_7': [0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628,
#   0.6006993055343628]}

# %%
plt.plot(hist.history['loss'], label='train loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# %%
plt.plot(hist.history['precision_7'], label='train acc')
plt.plot(hist.history['val_precision_7'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
y_pred = model.predict(X_test)

# %%
# Calculate the accuracy
test_preds = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
test_acc = np.sum(test_preds == y_true)/y_true.shape[0]

# Recall for each class
recall_vals = []
for i in range(3):
    class_idx = np.argwhere(y_true==i)
    total = len(class_idx)
    correct = np.sum(test_preds[class_idx]==i)
    recall = correct / total
    recall_vals.append(recall)

classes = [0,1]
# Calculate the test set accuracy and recall for each class
print('Test set accuracy is {:.3f}'.format(test_acc))
for i in range(2):
    print('For class {}, recall is {:.3f}'.format(classes[i],recall_vals[i]))

print("Weighted F score is {:.3f}".format(test_acc))
# print("Weighted F score is {:.3f}".format(calculate_weighted_f_score(y_true, y_pred)))
# Out:
# Test set accuracy is 0.608
# For class 0, recall is 1.000
# For class 1, recall is 0.000
# Weighted F score is 0.608
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in long_scalars
#   if sys.path[0] == '':

# %% [markdown]
# # Completely New Model Build

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D

# %%
model = Sequential()
model.add(Conv2D(32, (1, 3), activation='relu', padding='same', input_shape=(X_train.shape[1], X_train.shape[2], X_train.shape[3])))
model.add(MaxPooling2D((1, 4), strides=4))
model.add(Dropout(0.7))
model.add(Conv2D(64, (1, 3), activation='relu', padding='same',))
model.add(MaxPooling2D((1, 3), strides=3))
model.add(Dropout(0.7))
model.add(Conv2D(128, (1, 3), activation='relu', padding='same',))
model.add(MaxPooling2D((1, 2), strides=2))
model.add(Dropout(0.7))

model.add(Flatten())
model.add(Dense(1000,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(3,activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 5, 24, 32)         128
#
#  max_pooling2d_22 (MaxPoolin  (None, 2, 6, 32)         0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 2, 6, 32)          0
#
#  conv2d_23 (Conv2D)          (None, 2, 6, 64)          6208
#
#  max_pooling2d_23 (MaxPoolin  (None, 1, 2, 64)         0
#  g2D)
#
#  dropout_15 (Dropout)        (None, 1, 2, 64)          0
#
#  conv2d_24 (Conv2D)          (None, 1, 2, 128)         24704
#
#  max_pooling2d_24 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 1000)              129000
#
#  dense_9 (Dense)             (None, 500)               500500
#
#  dense_10 (Dense)            (None, 3)                 1503
#
# =================================================================
# Total params: 662,043
# Trainable params: 662,043
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
batch_size = 12
hist = model.fit(X_train, y_train, batch_size=batch_size, epochs=50, validation_data=(X_val, y_val))

##### LABLES NEED TO BY 1x3 ARRAY
# Out:
# Epoch 1/50
# 352/352 [==============================] - 10s 5ms/step - loss: 1.1026 - accuracy: 0.3635 - val_loss: 1.0981 - val_accuracy: 0.3671
# Epoch 2/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.0940 - accuracy: 0.3780 - val_loss: 1.0986 - val_accuracy: 0.3671
# Epoch 3/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.0958 - accuracy: 0.3765 - val_loss: 1.0988 - val_accuracy: 0.3671
# Epoch 4/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.0938 - accuracy: 0.3770 - val_loss: 1.0990 - val_accuracy: 0.3671
